# %%
from bs4 import BeautifulSoup
import requests
import json

# %%
import csv
def get_courses_data(filename):
    course_data = list()
    with open(filename, newline='') as csvfile:
        spamreader = csv.reader(csvfile, delimiter=',', quotechar='"')
        return list(spamreader)
    
#get_courses_data("udemy_dev.csv")

# %%
def get_udemy_course_data(page):
    #Get page html object
    full_page = "https://www.udemy.com/" + page
    html = requests.get(full_page, timeout=60).text
    soup = BeautifulSoup(html, 'html.parser')
    
    course_title = soup.find("h1", {"class":"clp-lead__title"}).get_text().strip()
    course_id = soup.find("div", {"data-course-id":True})["data-course-id"]
    
    return course_title, course_id
    
#get_udemy_course_data("data-science-deep-learning-in-python")

# %%
def get_udemy_curriculum_by_id(courseid):
    full_page = "https://www.udemy.com/api-2.0/courses/" + courseid + "/public-curriculum-sections"
    curriculum_data = requests.get(full_page, timeout=60).json()
    
    curriculum = list()
    
    for content in curriculum_data['results']:
        content_title = content['title']
        content_subtitles = [{"t": subcont['title']} for subcont in content["items"]]
        
        curriculum.append({"t":content_title, "c":content_subtitles})
    
    return curriculum
    
#get_udemy_curriculum_by_id('364426')

# %%
def get_udemy_curriculum(page):
    course_title, course_id = get_udemy_course_data(page)
    curriculum = get_udemy_curriculum_by_id(course_id)
    
    return {"t":course_title, "i":course_id, "c": curriculum}

#c = get_udemy_curriculum("machine-learning-na-pratica")
#print(c)

# %%
def save_course_data(course_data):
    json_string = json.dumps(course_data)
    filename = "".join(["udemy_data/",course_data['i'],".json"])
    f = open(filename, 'w')
    f.write(json_string)
    f.close()
#save_course_data(get_udemy_curriculum("machine-learning-com-weka-e-java"))

# %%
courses_data = get_courses_data("udemy_dev.csv")
list_size = len(courses_data)

for i, (course_id, course_title) in enumerate(courses_data[3770:]):
    print(course_title)
    try:
        curriculum = get_udemy_curriculum_by_id(course_id)
        save_course_data({"t":course_title, "i":course_id, "c": curriculum})
    except:
        pass
    print("Done {}/{}".format(i+1, list_size-3770))
# Out:
# Start with Basic HTML
# Done 1/1125
# Swift 2 Beyond the Basic 2016
# Done 2/1125
# HTML5 & Css3 From Basic Till Advance
# Done 3/1125
# The Java Beginners Guide: The Complete Beginner's Guide
# Done 4/1125
# A developers guide to IBM Events
# Done 5/1125
# Learn Android From Scratch: The Easy Beginner's Guide
# Done 6/1125
# Ruby Programming Fundamentals
# Done 7/1125
# Beginners Guide to Programming in Android
# Done 8/1125
# Introduction to Using JavaScript on Web Pages
# Done 9/1125
# The Philosophy of FileMaker - Part 4
# Done 10/1125
# Android App Entwicklung mit Java: Der umfassende Kurs
# Done 11/1125
# C++ C? b?n dành cho ng??i m?i h?c l?p trình
# Done 12/1125
# Swift  IOS 9 ?????? ??????? ?????? ????? ???????
# Done 13/1125
# Der komplette Android 6 Entwickler Kurs - Erstelle 14 Apps
# Done 14/1125
# Android Studio ile Uygulama Geli?tirme E?itimi-1
# Done 15/1125
# JavaScript: de cero hasta los detalles
# Done 16/1125
# Curso de Symfony3 - Domina el framework PHP más completo
# Done 17/1125
# Swift ile iOS 8 Uygulamalar? Geli?tirmeye Ba?lay?n
# Done 18/1125
# Desenvolvendo uma aplicação GUI com Python e Tkinter
# Done 19/1125
# ?????????????
# Done 20/1125
# ????? ?????? ?????? ????? ??????????  ???????? ???? ???
# Done 21/1125
# ???? ???? ?????? ???? ???????? ??????? ???????? ?????? ???
# Done 22/1125
# AngularJS - Desde Hola Mundo hasta una Aplicación
# Done 23/1125
# ???????????????????????????? 24 ??????? ????????????????
# Done 24/1125
# Spiele entwickeln mit Unity - Erstelle eigene Games in C#
# Done 25/1125
# Iniciando com Ionic 2
# Done 26/1125
# learn c++ language in arabic
# Done 27/1125
# Crie sites do zero com HTML5 & CSS3
# Done 28/1125
# Unity 5 + C#: Simplificando o Desenvolvimento de Jogos
# Done 29/1125
# Aprende Ionic 2 desde cero: Curso inmersivo
# Done 30/1125
# ?????????????????????? ???????? App ?? iOS 10
# Done 31/1125
# Unreal Engine 4 pour débutants | Guide Complet
# Done 32/1125
# Make Android Apps with ease - NO Coding (Arabic)
# Done 33/1125
# JavaScript: Verstehe die seltsamen Teile
# Done 34/1125
# Learn Python 3 in Under 1 Hour!
# Done 35/1125
# Logo Quiz Game iOS - Programmatically without Storyboards
# Done 36/1125
# The Complete Software & Web Development Course for Beginners
# Done 37/1125
# Web Development: HTML5, CSS3, PHP, OOP and MySQL database
# Done 38/1125
# Real World Hadoop - Upgrade Cloudera and Hadoop hands on
# Done 39/1125
# Swift - Learn by doing
# Done 40/1125
# WordPress 4+ Unveiled - Up To Date Trainings - ALWAYS
# Done 41/1125
# Delphi Flappy Bird Clone (Türkçe-English)
# Done 42/1125
# Learn the basics of HTML in a hour!
# Done 43/1125
# Complete AJAX Using Bootstrap, PHP From Basic To Advanced.
# Done 44/1125
# Diseño Web Desde Cero a Avanzado 40h Curso Completo
# Done 45/1125
# iOS 10 et Swift 3 : Le cours complet
# Done 46/1125
# ???? ????? ??????? ??????? ?? ????? ??? ???????? swift
# Done 47/1125
# Aprende C# creando un juego en Unity 5: de cero a experto
# Done 48/1125
# ?????? JavaScript ?????
# Done 49/1125
# Começando com Android - Crie 6 Apps
# Done 50/1125
# Formation Complète Développeur Web
# Done 51/1125
# ???? ????  ?????? ???? ???????? ??????? ???????? ???? ?????
# Done 52/1125
# Primeros Pasos con Swift
# Done 53/1125
# Curso Completo do Desenvolvedor NodeJS e MongoDB
# Done 54/1125
# Cómo crear una aplicación para Android
# Done 55/1125
# Curso de iOS 9 en Objective-C: de Cero a Experto
# Done 56/1125
# Desarrollo de aplicaciones nativas para Android
# Done 57/1125
# Crea páginas web responsive con Bootstrap
# Done 58/1125
# ?2??????????? PHP???
# Done 59/1125
# Android Nougat | Curso de Desarrollo de Aplicaciones Móviles
# Done 60/1125
# Curso de TypeScript - El lenguaje utilizado por Angular 2
# Done 61/1125
# C Programmieren - Praxisorientierter Einsteiger Kurs
# Done 62/1125
# Desarrollador Web Profesional
# Done 63/1125
# Cómo Programar para Emprendedores - HTML y CSS
# Done 64/1125
# Desarrollo de Aplicaciones móviles con App Inventor
# Done 65/1125
# Fundamentos de Programación con Java
# Done 66/1125
# C# Windows Forms Application para iniciantes
# Done 67/1125
# Aprende Wordpress sin conocimientos previos y gana dinero
# Done 68/1125
# C# Grundlagen
# Done 69/1125
# Crea tu Primer Sitio Web con Wordpress de manera Fácil
# Done 70/1125
# Python 3 para Iniciantes
# Done 71/1125
# Objektorientierte Entwicklung mit PHP 7
# Done 72/1125
# Curso Completo de Desenvolvimento WEB - Crie 6 Projetos
# Done 73/1125
# Python Bootcamp 2016 - Lerne Effektive Python Programmierung
# Done 74/1125
# PHP-Bootcamp 2016: Vom Anfänger zum PHP-Entwickler
# Done 75/1125
# Java y BlueJ | Introducción a las Bases de la Programación
# Done 76/1125
# Aprende jQuery, jQuery Mobile y jQuery UI desde cero
# Done 77/1125
# Ruby on Rails - Curso Completo
# Done 78/1125
# AngularJS et Node.js | Guide Complet
# Done 79/1125
# ????7???????????Web???????????????2015????
# Done 80/1125
# ???? ???? ?????? ????? ??? ????????  ???????? ???? ????
# Done 81/1125
# ????????? Python 3 ??
# Done 82/1125
# ?? HTML?CSS ??????
# Done 83/1125
# Aprende PHP desde cero con 36 ejercicios prácticos
# Done 84/1125
# Crear un API RESTful con Slim PHP y usarla con AJAX
# Done 85/1125
# Aprende Bases de Datos MySQL desde 0
# Done 86/1125
# ????????????????????????????iPhone????? Swift??
# Done 87/1125
# Débuter avec C# et Unity | Guide Complet
# Done 88/1125
# Java Programmieren für Anfänger - Der Ultimative Java Kurs
# Done 89/1125
# ????????????05 ??????????
# Done 90/1125
# ???? ???? ?????? ???? ???????? ???????  ???????? ?????? ???
# Done 91/1125
# ? 5??????????? Java?????????
# Done 92/1125
# 60 Minutes of Swift - Swift 2 Grundlagen
# Done 93/1125
# WordPress Websites erstellen - Die Anleitung für Beginner
# Done 94/1125
# Apprendre HTML et CSS et créer un site Web
# Done 95/1125
# Aprendendo HTML em 1 hora
# Done 96/1125
# ?????????? ??? ???????? ???????? ???? ???? ???
# Done 97/1125
# Web Scraping com Python e Beautiful Soup
# Done 98/1125
# ??  jQuery ???????????
# Done 99/1125
# Aprende Programación con C# y Visual Studio desde cero
# Done 100/1125
# El completo desarrollador de  iOS 10 - Crea apps con Swift 3
# Done 101/1125
# Diseño Web Responsive con el Framework Bootstrap 3
# Done 102/1125
# Aprende a crear Blogs profesionales con Google Blogger
# Done 103/1125
# Curso Completo de jQuery + 10 Projetos Práticos
# Done 104/1125
# HTML5 e CSS3 para Iniciantes + Criação de Portal de Notícias
# Done 105/1125
# Aprenda a programar em Swift - IOS
# Done 106/1125
# Iniciación a Swift 3 - Mi primera App con iOS 10
# Done 107/1125
# VB.net & SQL
# Done 108/1125
# ??? ?? iOS10 and Swift3
# Done 109/1125
# Lógica Programación: Aprende Programar en Cualquier Lenguaje
# Done 110/1125
# Core Data mit Swift im Detail
# Done 111/1125
# Learning Java Bit By Bit In Arabic
# Done 112/1125
# Desarrollo Web con Spring 4
# Done 113/1125
# ???? ????? ???? ???? ????????  ???????? ???? ???? ????
# Done 114/1125
# Jogos para iOS com Stencyl
# Done 115/1125
# Swift 2 ?????? ?????? ????????? ?????? ??????? ????????
# Done 116/1125
# Curso desarrollo web - HTML | CSS | Javascript | jQuery
# Done 117/1125
# Aprenda Unity 5 - Como criar um jogo de plataforma 3D
# Done 118/1125
# iOS 10 y Swift 3 |Desarrollo de APPS desde Cero
# Done 119/1125
# Curso Completo do Desenvolvedor Web
# Done 120/1125
# iOS 10 Apps mit Swift 3, der umfassende Kurs
# Done 121/1125
# Curso de Desarrollo Web Completo 2.0
# Done 122/1125
# ?Swift3.0????????????????????????iOS 10??? 20???????????????
# Done 123/1125
# Curso Completo do Desenvolvedor Android M - Crie 10 Apps
# Done 124/1125
# Curso de Angular 2 en Español - Crea webapps desde cero
# Done 125/1125
# iOS 9 y Swift 2 Completo: Aprende creando 15 Apps reales
# Done 126/1125
# Master en Programación de Videojuegos con Unity 5 y C#
# Done 127/1125
# Fundamentos prácticos de programación desde cero
# Done 128/1125
# Python 3 al completo desde cero para principiantes +18h
# Done 129/1125
# iOS 9 y Swift 2 | Curso Completo y Desde Cero
# Done 130/1125
# Curso de iOS 10 y Swift 3: de Cero a Experto
# Done 131/1125
# ????2???????? Python ????????
# Done 132/1125
# Curso Completo do Desenvolvedor Android - Crie 15 Apps
# Done 133/1125
# PHP y MYSQL: El Curso Completo, Practico y Desde 0 !
# Done 134/1125
# Desarrollo web full-stack con Symfony 3 y Angular 2
# Done 135/1125
# Der komplette Web-Entwickler Kurs 2.0 -Erstelle 25 Webseiten
# Done 136/1125
# Der Komplette Web-Entwickler Kurs - Erstelle 14 Webseiten
# Done 137/1125
# Swift 2.2 und iOS9 - App Entwicklung für iPhone und iPad
# Done 138/1125
# Curso Completo do Desenvolvedor iOS 9 - Crie 18 Apps
# Done 139/1125
# Swift3 ??????
# Done 140/1125
# Curso Completo do Desenvolvedor iOS 10 - Crie 14 Apps
# Done 141/1125
# ??????????????????iOS 9?????????
# Done 142/1125
# WordPress Avanzado Custom Post Types, Taxonomías y Metaboxes
# Done 143/1125
# Programador web: PHP y MySqli Profesional ¡Fácil y Práctico!
# Done 144/1125
# ?????????????iOS ?????????iOS 10 ?Swift 3???
# Done 145/1125
# Crea tu API RESTful con Laravel, el Framework para PHP
# Done 146/1125
# ?????? JavaScript ??????????? Windows? node.js NW.js
# Done 147/1125
# Introducción al desarrollo de temas WordPress
# Done 148/1125
# Curso de C++ - Intermediário
# Done 149/1125
# Cours Complet développeur iOS 9 - Créez 18 Applications
# Done 150/1125
# ????? Sublime Text 3 ?????
# Done 151/1125
# UITableView mit Swift - von A bis Z
# Done 152/1125
# Aprende a crear una página web desde 0
# Done 153/1125
# Probar Django | Construir una Aplicación Web en Python
# Done 154/1125
# Curso de Bioinformática com Biopython
# Done 155/1125
# ASP NET MVC 5 (C#): Desarrollando un portafolio profesional
# Done 156/1125
# Crea tu propio Pokemon Go para iOS
# Done 157/1125
# Aprenda PHP em 178 videoaulas
# Done 158/1125
# Lógica de Programação com Python e CodeSkulptor
# Done 159/1125
# Crie Uma Loja Virtual com WordPress e WooCommerce
# Done 160/1125
# Programador web: Cookies y Sesiones en PHP
# Done 161/1125
# 55+ Herramientas de desarrollo y diseño web
# Done 162/1125
# Dominando WordPress Paso a Paso y Desde Cero
# Done 163/1125
# ?3??????????? Ruby on Rails 4 ???Ruby???????OK??
# Done 164/1125
# Aprende Laravel: Crea un Gestor de Fotos con Laravel y PHP
# Done 165/1125
# ????????????03 ??????? Facebook ????
# Done 166/1125
# Criando Páginas Web com o GitHub Pages
# Done 167/1125
# ????? Mobile App ???? Angular JS ??? Ionic Framework
# Done 168/1125
# De Novato a Desarrollador Exitoso
# Done 169/1125
# Unity3D for Android and IOS ?????? ??????? ????? ???????
# Done 170/1125
# ??? ?? iOS9 and Swift2
# Done 171/1125
# Aprende Java Enterprise Edition (JavaEE) paso a paso
# Done 172/1125
# Programación iOS para iPhone y iPad
# Done 173/1125
# Programmieren Lernen - Swift 3 für Einsteiger
# Done 174/1125
# ???? ????? ??????? ????? ?????? ????????? Unity Engine
# Done 175/1125
# Construa um E-Commerce com Python 3 e Django
# Done 176/1125
# ???????? jQuery??
# Done 177/1125
# Introducción a SQL con Oracle 11g
# Done 178/1125
# Dominando Banco de Dados com MySQL
# Done 179/1125
# Crie Android Wear Watch Faces de forma simples!
# Done 180/1125
# Cómo Programar para Emprendedores - JavaScript
# Done 181/1125
# Aprende Angular 2 en Español!
# Done 182/1125
# Curso de C++: Básico a Avanzado
# Done 183/1125
# Der Ultimative JavaFX 8 GUI Kurs - Dein Weg zu tollen GUIs
# Done 184/1125
# Der komplette NodeJS Kurs - Vom Anfänger zum Profi
# Done 185/1125
# Chrome ?????????
# Done 186/1125
# AngularJS - Entwickle eigene Angular Webapplikationen
# Done 187/1125
# Imparare a programmare: Corso Javascript per principianti
# Done 188/1125
# Python 3 na Web com Django (Básico e Intermediário)
# Done 189/1125
# Aprende Efectos CSS3
# Done 190/1125
# Rume Academy - SpriteKit Einführung in Swift
# Done 191/1125
# Máster PHP ¡Dinamismo web al alcance de todos!
# Done 192/1125
# Introducción al Desarrollo de Aplicaciones Web con Symfony
# Done 193/1125
# Curso Unity 5 Creando un juego para PC
# Done 194/1125
# Débuter en PHP et MySQL | Guide Complet
# Done 195/1125
# UML - Guia Básico para Análise e Projeto de Sistemas
# Done 196/1125
# L?p trình H??ng ??i t??ng v?i C++ c? b?n ??n nâng cao
# Done 197/1125
# Programación orientada a objetos con JavaScript
# Done 198/1125
# GameMaker Studio sin programar desde cero
# Done 199/1125
# Apprendre Javascript et créer un jeu en ligne
# Done 200/1125
# Temel Android
# Done 201/1125
# JavaScript??????????
# Done 202/1125
# Python Pour Débutants: Code Comme Un Pro
# Done 203/1125
# AspNet ve Bootstrap Kullanarak Mobile Uygulama Yapal?m
# Done 204/1125
# ?3???????????Linux?????????CentOS 7?PHP 7?Docker???
# Done 205/1125
# Game Maker ile S?f?rdan Oyun Yap?m? - Bir Oyun Yap?mc?s? Ol
# Done 206/1125
# Desarrollo Web Rapido - HTML5,  CSS3 y Bootstrap 3
# Done 207/1125
# LESS de cero a experto
# Done 208/1125
# ????? ??????? ????????? ???????? HTML, CSS, Javascript
# Done 209/1125
# JavaFX 8 - Der Einstieg in die Java-GUI Programmierung
# Done 210/1125
# CSS desde cero: Desarrollo Web/HTML/CSS3 para profesionales
# Done 211/1125
# ?????? ??????? ????? ????? - ?? ????? 14 ???? ??????
# Done 212/1125
# Java e Orientação a Objetos
# Done 213/1125
# Aprende a programar para Emprendedores - Javascript
# Done 214/1125
# Wordpress For Entrepreneurs: The Install Cheatsheet
# Done 215/1125
# Build the Next Great Video Game using the Hottest Tools
# Done 216/1125
# Create your own Video Game easy without Coding
# Done 217/1125
# WordPress 2016 A TO Z Master Training In Hindi & Urdu
# Done 218/1125
# Computer Vision with Python
# Done 219/1125
# Python for Beginners: From Noob to Expert in 22+ Hours
# Done 220/1125
# Big Data Intro for IT Administrators, Devs and Consultants
# Done 221/1125
# Mastering  Front-End: HTML for Beginners
# Done 222/1125
# C Programming For Beginners:  A Layman's Approach
# Done 223/1125
# Real World Vagrant - Build an Apache Spark Development Env!
# Done 224/1125
# Learn Angular 2 from Beginner to Advanced
# Done 225/1125
# Learn Python 3 in Under 1 Hour!
# Done 226/1125
# Linguagem R para Iniciantes
# Done 227/1125
# jQuery: Animationen und Effekte für deine Webseite
# Done 228/1125
# Curso de Zend Framework 2 - Desarrollo web avanzado con PHP
# Done 229/1125
# HTML desde cero: Desarrollo Web/HTML5/FTP para profesionales
# Done 230/1125
# Introduction à Bootstrap | Rapide & Facile
# Done 231/1125
# Développement rapide avec Bootstrap | Guide Complet
# Done 232/1125
# Fundamentos de C# para Principiantes
# Done 233/1125
# Scrum 100 Lero Lero
# Done 234/1125
# Videojuegos 2D: Aprende SpriteKit desde cero
# Done 235/1125
# Apprenez à créer des jeux vidéo avec Unity 5 et C#
# Done 236/1125
# Desarrollo de Apps para Android
# Done 237/1125
# Introducción profesional a PHP
# Done 238/1125
# Jogo de Plataforma em Realidade Aumentada - Unity 5
# Done 239/1125
# De PSD a HTML5
# Done 240/1125
# Introducción a Objective C & iOS
# Done 241/1125
# Crea Veloces APIs RESTful con Lumen y Homestead de Laravel
# Done 242/1125
# Criação de Arte para Games e Apps
# Done 243/1125
# ??????????? ???AngularJS??
# Done 244/1125
# Apprendre (PHP et) MySQL et créer un site Web dynamique
# Done 245/1125
# Android 4 All In Arabic
# Done 246/1125
# Cómo promocionar tu app o juego móvil con Tappx
# Done 247/1125
# Google Web Designer Ba?lang?ç
# Done 248/1125
# Scala for Java Developers (in Russian)
# Done 249/1125
# ?????? Java???????????????
# Done 250/1125
# Torne-se um desenvolvedor Magento - Certificação Front End
# Done 251/1125
# Java en acción: un caso práctico
# Done 252/1125
# Desarrollo de juegos web en JavaScript y HTML5 (Phaser)
# Done 253/1125
# Aprenda jQuery - Escreva menos e faça mais
# Done 254/1125
# Primeros pasos en MongoDB
# Done 255/1125
# Clientes HTTP con Laravel: Usa y Consume Servicios y APIs
# Done 256/1125
# Spiele programmieren im Game Maker: Studio
# Done 257/1125
# Aprende el API WebSQL database de HTML5
# Done 258/1125
# Guida pratica ai form html5
# Done 259/1125
# Sichere Web-Entwickling erlernen in der Praxis mit PHP 7
# Done 260/1125
# REST Api con PHP: desde básico hasta un proyecto profesional
# Done 261/1125
# Android Studio ile Uygulama Geli?tirme E?itimi-2
# Done 262/1125
# Git fundamental - Aprende lo importante desde cero
# Done 263/1125
# Überblick: Wie werde ich Programmierer?
# Done 264/1125
# Conviértete en un Desarrollador Web desde cero Paso a Paso
# Done 265/1125
# Flappy Bird 3D em Realidade Aumentada com Unity e Vuforia
# Done 266/1125
# ?????? ??????? ?????? ??????? ??????? ????? 3 iOS10, Swift3
# Done 267/1125
# Curso Completo de Shell Script
# Done 268/1125
# Tu primer proyecto web en internet con WordPress
# Done 269/1125
# Sublime Text ¡Sé más productivo y desarrolla más rápido!
# Done 270/1125
# HTML5 para Diseñadores Nivel I - Conceptos de etiquetado web
# Done 271/1125
# jQuery: De cero a avanzado mediante ejercicios prácticos.
# Done 272/1125
# Lerne das Framework Laravel (PHP) in einfachen Schritten!
# Done 273/1125
# Crea un Landing Page con HTML5, CSS3, Bootstrap y WordPress
# Done 274/1125
# Curso de Desarrollo de Juegos para iOS, Android y Facebook
# Done 275/1125
# Android para iniciantes
# Done 276/1125
# Curso de Linguagem C para Iniciantes
# Done 277/1125
# E-commerce per tutti con Prestashop 1.6
# Done 278/1125
# Pareto para Programadores-El eslabon Perdido del seniority
# Done 279/1125
# WORDPRESS: ??? ??????? ????
# Done 280/1125
# ??????????? Atom
# Done 281/1125
# Hybrid cross platform mobile development IOS and ANDROID
# Done 282/1125
# Trabajando con datos en la Web
# Done 283/1125
# Moodle 2 ??? ????????
# Done 284/1125
# Aprenda PHP y SQLite
# Done 285/1125
# ken-cens.com??HTML,CSS,Javascript,php,mySQL????(??3????????)
# Done 286/1125
# Modelagem de Dados em Banco de Dados Relacional
# Done 287/1125
# ????9??????Unity ??????????????????????? C#???????
# Done 288/1125
# Apprendre jQuery et créer une page Web interactive
# Done 289/1125
# HTML5 e CSS3: La guida completa per lo sviluppatore WEB
# Done 290/1125
# Aprende Node JS Fácilmente - en Español
# Done 291/1125
# IOS9 ?????? ???????? ?????? ?????? ???? ??????? ??? ???????
# Done 292/1125
# Começando a Programar em C++
# Done 293/1125
# Crie jogos com o GameSalad!
# Done 294/1125
# Ruby on Rails en español
# Done 295/1125
# Android Programlama için Java ve XML
# Done 296/1125
# Aprenda a trabalhar com telas em Swift -IOS
# Done 297/1125
# Iluminação para Unity 5 - Do Básico ao Avançado
# Done 298/1125
# Laravel 5 Express
# Done 299/1125
# Aprenda Construct2 - Como criar um jogo de plataforma 2D
# Done 300/1125
# Java Maven: Introduccion paso a paso para no expertos
# Done 301/1125
# Crea una Agenda de Contactos con iOS, Swift, y Core Data
# Done 302/1125
# Aprende jQuery y jQuery UI de forma fácil y práctica
# Done 303/1125
# C# ?le LINQ (Language Integrated Query) Windows Form App.
# Done 304/1125
# ?????????????????????Unity5????
# Done 305/1125
# Der ultimative Python 3 Kurs für Anfänger
# Done 306/1125
# Wie du deinen WordPress Blog mit HTML in den Griff bekommst!
# Done 307/1125
# Padrão\u000b MVC - explicado e aplicado
# Done 308/1125
# Aprende Spring MVC de cero a experto.
# Done 309/1125
# Solo Swift
# Done 310/1125
# ?? ?????? ?????? ?????? ???? ???? ???? ???????
# Done 311/1125
# ??? ?? iOS9 and Objective-C
# Done 312/1125
# Xây d?ng web app v?i ReactJS
# Done 313/1125
# ????????iOS???????
# Done 314/1125
# Analista Ágil: Como Ser Ágil em 10 Passos
# Done 315/1125
# 3D Studio Max - Personagem para Games
# Done 316/1125
# Acesso Remoto com Unity
# Done 317/1125
# Javascript  ES6 : La guida mancante in italiano
# Done 318/1125
# CSS3: La guida pratica e veloce di CSS per  sviluppatori web
# Done 319/1125
# Angular.js Desde Cero, Aprende Creando una APP Web
# Done 320/1125
# Concevez votre site web avec PHP et MySQL
# Done 321/1125
# ODATA Services im SAP UI5 Umfeld
# Done 322/1125
# IOS 10 ?????? ??????? ????? ??????? ???
# Done 323/1125
# UNITY: ??? ??????? ???? ????? ???????? ?????????
# Done 324/1125
# Comienza con SQL: Descarga los datos tu mismo con SQL!
# Done 325/1125
# ?????????????Android????????Android Studio 2.1?Java 8???
# Done 326/1125
# Introducción a JavaScript
# Done 327/1125
# Desarrollo de Videojuegos 2D en Unity 3D 5
# Done 328/1125
# Experto de Photoshop a WordPress creando 4 Themes/Plantillas
# Done 329/1125
# ??????? HTML ? CSS ?? ????????? ?????
# Done 330/1125
# Apprendre WordPress – Créer un Blog et un Site E-commerce
# Done 331/1125
# PHP7: La guida completa per sviluppatori web
# Done 332/1125
# Linguagem de Programação C# Nível Básico
# Done 333/1125
# Maratona de Programação - A Arte de Competir
# Done 334/1125
# Débute avec le langage C | Guide Complet
# Done 335/1125
# Aprende Spring Framework de la manera más simple en español
# Done 336/1125
# Mit WooCommerce einen erfolgreichen Wordpress Shop erstellen
# Done 337/1125
# Aprendendo a programar em Java
# Done 338/1125
# Desarrollo web con Laravel 4
# Done 339/1125
# Introducción al Testing de Software: para Principiantes!
# Done 340/1125
# Aprende los APIS de HTML5 sin dolor
# Done 341/1125
# jQuery y AJAX Desde Cero - La Guía Definitiva
# Done 342/1125
# Instala MySQL y SQL Server 2008 R2 en unos cuantos pasos
# Done 343/1125
# Aprende a crear video juegos con Stencyl
# Done 344/1125
# C# programmieren lernen - der ultimative C Sharp Kurs
# Done 345/1125
# ??????R ??????
# Done 346/1125
# Das Java - Bootcamp: Lerne Java für Hobby, Beruf & Studium
# Done 347/1125
# Delphi I - Sistema de Estoque em 175 videoaulas
# Done 348/1125
# Swift in Arabic  ????? ?????? ??????? - ????? ??????? ?????
# Done 349/1125
# Introducción teórica a los frameworks de desarrollo para PHP
# Done 350/1125
# Rails??????Sinatra????Rails?????????
# Done 351/1125
# Aprende Accesibilidad Web paso a paso
# Done 352/1125
# Empieza tu camino hacia la programación web con HTML
# Done 353/1125
# Curso Completo de Desarrollo de Apps para Apple Watch
# Done 354/1125
# Programação Orientada a Objetos com Python
# Done 355/1125
# Apprendre PHP et créer un formulaire de contact
# Done 356/1125
# Desarrollo Web con JSP y Servlets
# Done 357/1125
# Introduccion a CodeIgniter
# Done 358/1125
# JavaScript Experts - Completo e passo a passo
# Done 359/1125
# Selenium???????????
# Done 360/1125
# Curso de Lógica de Programação com JAVA
# Done 361/1125
# ????????????C??
# Done 362/1125
# WordPress 4 de A à Z | Guide Complet
# Done 363/1125
# Fundamentos de Javascript
# Done 364/1125
# PL/SQL de ORACLE en Español
# Done 365/1125
# Java Programmierung: Erstelle perfekte GUI Apps mit JavaFX
# Done 366/1125
# A'dan Z'ye Front-End Geli?tirme (html5 css3 javascript)
# Done 367/1125
# C Sharp desde Iniciante a Profesional
# Done 368/1125
# Le langage Ruby de A à Z | Guide Complet
# Done 369/1125
# Passo a passo para criar um site Wordpress profissional
# Done 370/1125
# Crie aplicativos para Android/iOS com HTML, CSS e JavaScript
# Done 371/1125
# Monta un servidor web con Linux desde cero
# Done 372/1125
# PHP Object Oriented Programming E?itimi
# Done 373/1125
# Introducción a AngularJS, ¡Super Heróico!
# Done 374/1125
# Aprendendo CSS em 1 hora
# Done 375/1125
# De Objective-C a Swift
# Done 376/1125
# JSF - Java Server Faces 2.0
# Done 377/1125
# Swift 2 en español
# Done 378/1125
# ????????????01 ?????????
# Done 379/1125
# Aprende Joomla 3.4. sin dolor
# Done 380/1125
# Desarrollo de Juegos con JavaScript
# Done 381/1125
# Curso de iOS 9 y Swift 2: de Cero a Experto
# Done 382/1125
# Flappy Bird: Desarrollando nuestro juego para iOS8 en Swift
# Done 383/1125
# Core Data en iOS 9 y Swift | Curso de Persistencia de Datos
# Done 384/1125
# Android de A à Z | Guide Complet
# Done 385/1125
# Introduction au Développement Web
# Done 386/1125
# Maîtrise jQuery Comme un Pro | Guide Complet
# Done 387/1125
# Corso Javascript per imparare a programmare
# Done 388/1125
# Desarrollo Web Eficiente con SASS, NPM, Gulp y Web Workflows
# Done 389/1125
# iOS 8 und Swift - Der Einstieg in großartige App-Entwicklung
# Done 390/1125
# Minicurso Intel XDK
# Done 391/1125
# iPhone ??????? - ???????App??????
# Done 392/1125
# Aprende a crear webs desde cero con HTML Y CSS
# Done 393/1125
# Domina MATLAB en 2016 - Cómo Evitar los 9 Errores de Novato
# Done 394/1125
# Swift ile iOS Programlama Görsel E?itim Seti, 20+ Uygulama
# Done 395/1125
# HTML5, PhoneGap ???? ????? ??????? ??????? ?????? ????? ???
# Done 396/1125
# Programmieren lernen mit Python
# Done 397/1125
# Java Servlets y JSP - Desarrollo web con Java EE
# Done 398/1125
# Aprende Bootstrap y Foundation creando un sitio dos veces
# Done 399/1125
# Scrum: un marco para el desarrollo ágil de proyectos
# Done 400/1125
# Fundamentos de Java
# Done 401/1125
# Desenvolvimento de Aplicativos para Android
# Done 402/1125
# PHP Programmierung für Anfänger - Grundlagen
# Done 403/1125
# Angular 2 - Aprendiendo el framework del futuro
# Done 404/1125
# SQL Grundlagen verstehen und anwenden - das kannst auch Du
# Done 405/1125
# Programação em Java
# Done 406/1125
# Einstieg in C# - Software programmieren wie ein Profi
# Done 407/1125
# Corso JavaScript - ES6, NodeJS, ReactJS in italiano (Lite)
# Done 408/1125
# Make Android Apps Without Code  in Arabic
# Done 409/1125
# Aprende AngularJS Fácilmente - en Español
# Done 410/1125
# Curso iOS 9 con Swift 2,  con Base de datos y servicios web
# Done 411/1125
# Xamarin - Desenvolvimento para Android, iOS e WP.
# Done 412/1125
# Curso de Joomla 2.5 Paso a Paso
# Done 413/1125
# Oracle Database 12c Lenguaje de programación PL/SQL
# Done 414/1125
# Creando Restful services PHP-MYSQL
# Done 415/1125
# JavaScript pour débutants | Guide Complet
# Done 416/1125
# JQuery Mobile ile Mobil Tarafl? ?çerik Geli?tirmeye Ba?lay?n
# Done 417/1125
# Programmieren lernen: Swift von A bis Z
# Done 418/1125
# AppleTV Apps entwickeln, der umfassende tvOS Kurs
# Done 419/1125
# Desarrollo de Videojuegos en Unity 3d 4.3
# Done 420/1125
# Android selbst kompilieren wie ein Entwickler
# Done 421/1125
# Sublime ????????????
# Done 422/1125
# Curso de Python 3 Avançado
# Done 423/1125
# Spiele entwickeln mit Unity 5 - Das umfassende Training
# Done 424/1125
# Aprende a programar con Javascript desde cero
# Done 425/1125
# Aprende a programar con Ruby (desde cero y 100% en español)
# Done 426/1125
# Angular 2 - Leren en begrijpen
# Done 427/1125
# Be the Professional iOS/Android App Builder with Corona SDK
# Done 428/1125
# Curso Haskell para Iniciantes
# Done 429/1125
# Java e Orientação a Objetos para Iniciantes
# Done 430/1125
# Temel HTML - Yeni Ba?layanlar ?çin Kolay ve Pratik Ö?renme
# Done 431/1125
# Créez des applications mobiles sans programmer
# Done 432/1125
# JavaScript para Iniciantes
# Done 433/1125
# Curso de videojuegos para iOS - Flappy Bird
# Done 434/1125
# NodeJS,para principiantes,más de 10 proyectos ,100% práctico
# Done 435/1125
# Edge Animate Ba?larken
# Done 436/1125
# C# - Poderosa Linguagem de Programação
# Done 437/1125
# Bases del desarrollo web
# Done 438/1125
# Programación iOS Avanzada ¡De Padawan a Jedi!
# Done 439/1125
# S?f?rdan Türkçe ?os Programlama Ö?renin
# Done 440/1125
# ?????? ??????? ?????? ????? ??????? ????? IOS8 Swift
# Done 441/1125
# Bootstrap para Wordpress
# Done 442/1125
# Microsoft Azure de A à Z | Guide Complet
# Done 443/1125
# Yeni Ba?layanlar için Ado.Net hakk?nda her?ey
# Done 444/1125
# Monetiza tu app o videojuego con StoreKit
# Done 445/1125
# Learning Multi Language Admin Panel with Laravel 5
# Done 446/1125
# Apps de iOS y Android con HTML5 para Principiantes
# Done 447/1125
# ??????????IOS??/????????iPhoneAPP??/Xcode7.1 Swift2.0???
# Done 448/1125
# Gestión avanzada de datos con MongoDB
# Done 449/1125
# Découverte d'Unreal engine 4
# Done 450/1125
# de Cero a Trello
# Done 451/1125
# Magento para Lojistas e Empreendedores
# Done 452/1125
# Yeni Ba?layanlar ?çin Android Oyun Yap?m?
# Done 453/1125
# Aprende HTML5 desde 0 con 60 ejercicios practicos +proyectos
# Done 454/1125
# Curso Completo Unity 5
# Done 455/1125
# ??? ??! 5?? ?? ?? ??? ??? ???
# Done 456/1125
# Crea tu Tienda Online Sin Inventario y Aprende Dropshipping
# Done 457/1125
# WordPress für Anfänger und Fortgeschrittene
# Done 458/1125
# Ferramentas e dicas matadoras para o desenvolvimento Magento
# Done 459/1125
# Visual Studio ile C# Programlama
# Done 460/1125
# Objective-C für Swift Entwickler
# Done 461/1125
# Diseño responsivo con cajas flexibles CSS3
# Done 462/1125
# Java SE 7 Programlama
# Done 463/1125
# Curso Práctico SQL Server Reporting Services 2012 (SSRS)
# Done 464/1125
# Crie sites responsivos com Bootstrap
# Done 465/1125
# ?????????? ?????????? iOS ??? Android ???? HTML5
# Done 466/1125
# Aprende a programar en Python 3
# Done 467/1125
# ASP.NET MVC (C#) Desarrollando Una Red Social
# Done 468/1125
# Aprende PHP desde 0 con 40 ejercicios más proyectos reales
# Done 469/1125
# Mejora el FRONT-END de tu Web con Polymer sin tanto código
# Done 470/1125
# Basic iOS/Android App Development with Corona SDK
# Done 471/1125
# Dreamweaver + PHP + MySQL
# Done 472/1125
# AngularJS para aplicaciones web y móviles desde 0
# Done 473/1125
# Prestashop 1.6
# Done 474/1125
# ??? ??! ????? ???? ???
# Done 475/1125
# Domine o JavaScript
# Done 476/1125
# C# Programlama Dilini Ö?reniyorum : Tüm Seviyelere Uygun
# Done 477/1125
# Aprende Diseño Web Front-End - HTML, CSS y JavaScript
# Done 478/1125
# Kursus Lengkap Laravel 5 - Membangun 3 aplikasi web
# Done 479/1125
# Crea Apps para Android
# Done 480/1125
# Instala Google Analytics Universal con Google Tag Manager
# Done 481/1125
# SEO ????? (????)
# Done 482/1125
# SAP ABAP für Anfänger Teil 1 - programmieren lernen im SAP
# Done 483/1125
# Programación Panel View Plus desde cero
# Done 484/1125
# Construisez votre site Internet - portfolio avec Wordpress
# Done 485/1125
# Eigene App erstellen - kostenlos & einfach mit Chayns
# Done 486/1125
# ??????????????Unity 3D ???????
# Done 487/1125
# Aprende Android ¡Desarrollando una App Completa!
# Done 488/1125
# Programação em C#
# Done 489/1125
# Komple Web Geli?tirici Kursu : Front-end ve Back-end Kodlama
# Done 490/1125
# Tutorial práctico de XML: Crea y Valida Documentos XML
# Done 491/1125
# Aprende jQuery Mobile
# Done 492/1125
# Curso Completo de Oracle SQL e PL/SQL
# Done 493/1125
# Apple Watch - Desarrollo con WatchKit en Swift
# Done 494/1125
# Como Montar sua Loja Virtual - O Mapa Completo do E-commerce
# Done 495/1125
# iOS 9 y Swift2 crea apps iPhone desde Cero con servicios web
# Done 496/1125
# HTML5 Javascript CSS3 em 185 videoaulas
# Done 497/1125
# Desarrolla juegos HTML5 con canvas
# Done 498/1125
# Impara a programmare con Ruby on Rails e crea un marketplace
# Done 499/1125
# Desenvolvimento de Jogos com HTML5
# Done 500/1125
# WordPress 4.5 – von A bis Z verständlich erklärt!
# Done 501/1125
# Aprenda e Domine a Linguagem C
# Done 502/1125
# Responsive Web Design con CSS3, HTML5 y jQuery
# Done 503/1125
# Codeigniter Giri?
# Done 504/1125
# HTML + CSS - Kolay ve Pratik Ö?renme
# Done 505/1125
# Themeforest Wordpress, HTML ve PSD Tema Sat??? Nas?l Yap?l?r
# Done 506/1125
# Aprende JavaScript desde 0 con 60 ejercicios practicos
# Done 507/1125
# Dominando Joomla 3.2 Paso a Paso, Fácil y Rápido
# Done 508/1125
# Exporte seu jogo para mobile e publique no Google Play Store
# Done 509/1125
# Bases de datos en Internet: MySQLi ¡Fácil y práctico!
# Done 510/1125
# JavaScript Ö?reniyorum - 1
# Done 511/1125
# App: faites produire une App sans programmation en 20 jours
# Done 512/1125
# Aprende a programar desde cero - Lógica de Programación
# Done 513/1125
# ?? ??? ???? ?? ??(??)
# Done 514/1125
# Einstieg in GitHub: Entwickle Software wie die Profis
# Done 515/1125
# Desarrollo de Videojuegos con Stencyl Básico
# Done 516/1125
# Java e Orientação a Objetos
# Done 517/1125
# El lenguaje de programación Swift
# Done 518/1125
# Iniciandose en R
# Done 519/1125
# Fundamentos de programación en Java. Bases de la informática
# Done 520/1125
# Desenvolvimento web com Python e Django
# Done 521/1125
# Drupal 8 de A à Z | Guide Complet
# Done 522/1125
# Java SE IV - Crie sistemas em Java com MVC e Design Pattern
# Done 523/1125
# Laravel Dersleri
# Done 524/1125
# ????? Java ????? ??  [From 0 to 1 : Learn Java Programming]
# Done 525/1125
# PHP y MYSQL desde cero
# Done 526/1125
# Dreamweaver CC de A à Z | Guide Complet
# Done 527/1125
# Swift 3 ile IOS Programlama
# Done 528/1125
# Brackets & Edge Code - Fundamentos
# Done 529/1125
# Introducción a Oracle APEX 5.0
# Done 530/1125
# JavaScript – Das umfassende Training
# Done 531/1125
# Pruebas automáticas en Java
# Done 532/1125
# C# Orientação a Objetos - Introdução - K31
# Done 533/1125
# Curso IOS Objetive-C, desarrollo de app catálogo comercial
# Done 534/1125
# Aprende JSF con Netbeans paso a paso
# Done 535/1125
# Learn C Programming language in Marathi
# Done 536/1125
# Herramientas para el desarrollador web
# Done 537/1125
# iOS????????????????????????Instagram?????????????
# Done 538/1125
# Curso de Python: Aprenda de una forma práctica y dinámica.
# Done 539/1125
# Ruby on rails en español en videos cortos y simples
# Done 540/1125
# Apache WebServer: do Básico ao Avançado
# Done 541/1125
# Inteligencia de negocios en SQL  SERVER
# Done 542/1125
# Curso de Python para Iniciantes
# Done 543/1125
# Aprenda Banco de Dados,  SQL e Modelagem em 186 videoaulas
# Done 544/1125
# Crear Video Juegos sin saber Programar con Construct 2
# Done 545/1125
# MVC Dünyas?na Merhaba : Asp Net
# Done 546/1125
# Mit GameMaker Studio zum Game Maker
# Done 547/1125
# Interfaces Gráficas com\u000b JavaFX
# Done 548/1125
# Desarrollo de Videojuegos para iOS, Android y BlackBerry10
# Done 549/1125
# Nar Web Site PSD to CSS
# Done 550/1125
# Javascript  ES6 Avanzato
# Done 551/1125
# El Lenguaje Java. Las bases.
# Done 552/1125
# Magento - Crea tu Tienda Virtual paso a paso
# Done 553/1125
# ??Corona SDK?????????App(????)
# Done 554/1125
# ??? ??????? ???? ?? ???? c#
# Done 555/1125
# Delphi 10 seattle Firemonkey, Firedac,LiveBinding 103 videos
# Done 556/1125
# HTML Ö?reniyorum
# Done 557/1125
# Foundation for Emails 2: Diseña Increibles Emails Responsive
# Done 558/1125
# Windev 19 de A à Z | Guide Complet
# Done 559/1125
# SAP ABAP für Anfänger Teil 2 - programmieren lernen im SAP
# Done 560/1125
# C++?? ???? ????:  Qt/??? ?????? ??
# Done 561/1125
# Swift 3 y Azure Cloud | Tus Apps iOS con el Poder de la Nube
# Done 562/1125
# Oracle APEX. Integraciones y ejemplos nivel avanzado
# Done 563/1125
# HTML5 para Diseñadores Nivel II - Semántica, video y audio
# Done 564/1125
# Introdução à Produção de Games
# Done 565/1125
# Curso de PHP: desde cero hasta crear tu propio CMS
# Done 566/1125
# Bir Saatte Css Ö?ren
# Done 567/1125
# ???????? ?????????: Axure RP 7 ??????? ??????? ???????? ????
# Done 568/1125
# ????????? Swift 2 ? iOS 9 ???????
# Done 569/1125
# Twitter API????Swift?Twitter????
# Done 570/1125
# Aprende HTML en 5 simples pasos
# Done 571/1125
# K? izveidot m?jaslapu
# Done 572/1125
# Haber Sitesi Geli?tirme  K?s?m 1-2
# Done 573/1125
# Padrões de Projeto GoF (Design Patterns)
# Done 574/1125
# Loja Virtual com Wordpress
# Done 575/1125
# ???????????????? ?? Java ? ????
# Done 576/1125
# C# Essencial
# Done 577/1125
# Swift 3 Tutorial - der Crashkurs
# Done 578/1125
# Programmieren lernen mit Scratch
# Done 579/1125
# ???? ????? ???? Atlassian JIRA A to Z
# Done 580/1125
# 7 ???? AngularJS
# Done 581/1125
# Kendi Eticaret Siteni Geli?tir K?s?m 1-2
# Done 582/1125
# Spieleprogrammierung für Einsteiger
# Done 583/1125
# Crashkurs: Docker verstehen und einsetzen
# Done 584/1125
# Aprende Programación en C++ desde cero
# Done 585/1125
# HTML y CSS Completo
# Done 586/1125
# Introducción al desarrollo web con Symfony2
# Done 587/1125
# Curso completo de Core Data en Swift - Persistencia de datos
# Done 588/1125
# Loja virtual completa com Wordpress e Woocommerce (2016)
# Done 589/1125
# Linguagem Java para Iniciantes
# Done 590/1125
# Selenium IDE Tutorial Deutsch
# Done 591/1125
# Como criar um Jogo Completo para iOS - iPhone e iPad
# Done 592/1125
# ????????????06 ?????????????edm
# Done 593/1125
# JavaScript Ö?reniyorum - 2
# Done 594/1125
# LESS.js, un Nuovo Modo di Scrivere CSS
# Done 595/1125
# Fundamentos de la programación en Java Desde 0 hasta 1 juego
# Done 596/1125
# Web-Entwicklung unter Linux für Windows-Entwickler
# Done 597/1125
# Objective-C para verdaderos principiantes
# Done 598/1125
# PHP 5.4 und MySQL 5.5: Das Training für Einsteiger
# Done 599/1125
# Objetivos de Desarrollo Sostenible
# Done 600/1125
# TYPO3 CMS 7 – Das umfassende Training
# Done 601/1125
# Introducción a JavaScript
# Done 602/1125
# Algoritmos e Lógica
# Done 603/1125
# Java SE III - 207 videoaulas
# Done 604/1125
# Curso de videojuegos para iOS - Space Invaders
# Done 605/1125
# Programación RsLogix 5000 Plataforma Logix
# Done 606/1125
# Como crear aplicaciones para ANDROID con ejemplos prácticos
# Done 607/1125
# Delphi ile Android ve IOS Programlama 2 (?leri Seviye)
# Done 608/1125
# Grid infrastructure 12 c y Oracle 11gR2
# Done 609/1125
# Aprende SQL
# Done 610/1125
# Curso Completo de Delphi XE8
# Done 611/1125
# iOS Entwicklung - App Monetarisierung mit Swift 3 & iOS 10
# Done 612/1125
# Fundamentos de SCRUM, metodología ágil gestión de proyectos
# Done 613/1125
# App-Entwicklung mit Xamarin
# Done 614/1125
# Programación de Apps para NO Programadores
# Done 615/1125
# Introduction to Database
# Done 616/1125
# Aprende Java Nivel 1 - Primeros Pasos
# Done 617/1125
# Optimiza la Velocidad Web en WordPress
# Done 618/1125
# PHP & MYSQLI in Arabic
# Done 619/1125
# ?????????? ??????? ???? ? Unity 5
# Done 620/1125
# WordPress 4 Crea y administra tu sitio web sin programar
# Done 621/1125
# Les fondamentaux de Swift 3 - Formation Complète
# Done 622/1125
# Photoshop ??? ?????????? ?????????? (budding designers)
# Done 623/1125
# Curso de C# - Windows Forms - Para Iniciantes
# Done 624/1125
# Desarrollo web con bootstrap
# Done 625/1125
# Aprende Android con Java sin misterios y paso a paso.
# Done 626/1125
# ?????? ??????? ?????? ?????? ????? ????? ???? ?????
# Done 627/1125
# Aprenda Programação de CLP do zero
# Done 628/1125
# Meine eigene Website - Schritt für Schritt zum Webauftritt
# Done 629/1125
# Programação em C - Iniciante
# Done 630/1125
# FileMaker Pro: módulo básico
# Done 631/1125
# Curso de Lógica de Programação com PHP
# Done 632/1125
# Bootstrap 3 Para Principiantes: Aprende Desde Cero
# Done 633/1125
# WordPress Einsteigerkurs
# Done 634/1125
# ??? 3D? VR/AR ??? ? ???(??)
# Done 635/1125
# ??????????????? iOS App  ???????? Swift ??? Xcode
# Done 636/1125
# Probar Django 1.10 | Crear un Blog Dinámico
# Done 637/1125
# Programação Gráfica com Labview
# Done 638/1125
# Unity3D ile Oyun Haz?rlamaya Ba?lamak
# Done 639/1125
# iOS 10 Development - Build 15 iPhone Apps with Swift 3
# Done 640/1125
# Programmieren mit Swift – Das umfassende Training
# Done 641/1125
# Curso de Java WEB
# Done 642/1125
# Quiero ver mi App en el App Store
# Done 643/1125
# WordPress for Beginners
# Done 644/1125
# Introducción al Desarrollo de Juegos en Unity 5
# Done 645/1125
# XAMPP ve Navicat Giri?
# Done 646/1125
# ???(Unity) ?? : C#, ????? ???? ??? ?????
# Done 647/1125
# Joomla para Iniciantes
# Done 648/1125
# Desarrolla Aplicaciones Android con App Inventor desde Cero
# Done 649/1125
# MobileMatico Full >Todo Sobre Desarrollo y Marketing De Apps
# Done 650/1125
# Yii Framework 2 (Yii2) Workshop ????????????????????????
# Done 651/1125
# MVC con PHP: Aprende como funcionan los sitios Web actuales
# Done 652/1125
# HTML5 und CSS3: Die neuen Webstandards
# Done 653/1125
# Geodjango ile co?rafi bilgi sistemi uygulamar?
# Done 654/1125
# Programmieren lernen mit Java – Das Training für Einsteiger
# Done 655/1125
# Windows Phone 8 de 0 a 100
# Done 656/1125
# Web tasar?m & web sitesi nas?l yap?l?r ? html & css dersleri
# Done 657/1125
# ???????? ??? ?????????? ??????????
# Done 658/1125
# Développer des jeux avec Unreal engine 4
# Done 659/1125
# Integra Facebook en tu App o Videojuego
# Done 660/1125
# Desarrollo Web: aprende CSS3, jQuery, Html 5 y más
# Done 661/1125
# TDD Para Programadores Java
# Done 662/1125
# Android için Ba?tan Sona TETRIS Oyunu Yap?m?
# Done 663/1125
# Space Invaders para AppleTV: Crea un videojuego en una hora
# Done 664/1125
# Bir Saatte Html Ö?ren
# Done 665/1125
# Sistema Farmácia Java WEB
# Done 666/1125
# API - ???? ???? ????? ?????? ???????? ??????? ??? ????????
# Done 667/1125
# Curso Laravel 4, framework php rapido, potente y divertido.
# Done 668/1125
# VisuALG (Portugol) - Lógica de Programação do ZERO
# Done 669/1125
# Access - Sistema Financeiro
# Done 670/1125
# Crear Aplicaciones Android sin Programar
# Done 671/1125
# Curso en programación Swift 2 y iOS 9 de inicio a avanzado
# Done 672/1125
# Programación funcional en Java 8 con Lambdas y Streams
# Done 673/1125
# Android Spyware Disease & Medication " Arabic Version "
# Done 674/1125
# Ionic creación de aplicaciones móviles desde cero-práctico
# Done 675/1125
# Crea tu blog con WordPress
# Done 676/1125
# ???????? App iOS & Android ???? ActionScript 3.0 ????? 1 ???
# Done 677/1125
# Java ile Android Programlama -1 (Android Studio)
# Done 678/1125
# Construa seu site em WordPress de forma simples e rápida
# Done 679/1125
# Der Weg zum professionellen Softwareentwickler
# Done 680/1125
# Programación desde cero de PLC con RSLogix500
# Done 681/1125
# Control de versiones con Subversion
# Done 682/1125
# Programmazione: Python (Italiano - principanti)
# Done 683/1125
# Corso di HTML e CSS base
# Done 684/1125
# Datasnap Servidor de Aplicação em mais de 100 videoaulas
# Done 685/1125
# Learn The Basic's of Git & GitHub In Hindi
# Done 686/1125
# C# Orientação a Objetos - Intermediário - K31
# Done 687/1125
# Wordpress Profesional: Como Crear y Promocionar Un Sitio Web
# Done 688/1125
# C#.Net LINQ(Language Integrated Query) ?le Sorgulama
# Done 689/1125
# Arduino II - várias placas e interação com a web
# Done 690/1125
# Apprenez à coder en HTML et en CSS !
# Done 691/1125
# Les fondamentaux du C#
# Done 692/1125
# Git? ??? ?? ??
# Done 693/1125
# Entity Framework Code First ile Dinamik Asp.Net Uygulamalar?
# Done 694/1125
# Aprende Programación con Diagramas de Flujo
# Done 695/1125
# Java ile Android Programlama -2 (Android Studio)
# Done 696/1125
# Curso de ASP.NET com C#
# Done 697/1125
# WordPress?????????????????????
# Done 698/1125
# JavaScript??????JS?????
# Done 699/1125
# Aprende HTML5 y CSS3 desde cero y paso a paso
# Done 700/1125
# Kendi Stok Yönetimini Geli?tir K?s?m 1
# Done 701/1125
# Desarrollo de Aplicaciones en ASP.NET para la vida real
# Done 702/1125
# Fundamentos de Swift
# Done 703/1125
# Java para Web I - html, jsp, tomcat, postgresql
# Done 704/1125
# Dutch: Wordpress voor Beginners
# Done 705/1125
# PowerPoint 2016 das ultimative Training für Anfänger
# Done 706/1125
# Aprenda a criar sites sem precisar de códigos
# Done 707/1125
# Aprende Diseño web con HTML y CSS de forma fácil y práctica
# Done 708/1125
# ????????????02 ?????????
# Done 709/1125
# Realidade Aumentada: Crie aplicações com Unity3D e Vuforia
# Done 710/1125
# ???? ????? ????? ???? ???????? ???? ?? ????? - html & css
# Done 711/1125
# ASP . NET MVC 3 razor com c#
# Done 712/1125
# Desarrollo de videojuegos 2D con Game Maker Studio
# Done 713/1125
# jQuery para desarrolladores
# Done 714/1125
# Curso de Sites Responsivos
# Done 715/1125
# Curso de Android Studio
# Done 716/1125
# Membuat Blog dengan Laravel 5.x
# Done 717/1125
# Apps Nativas Android con HTML5
# Done 718/1125
# Programacion web con PHP y MySQL
# Done 719/1125
# Creando Sitio web desde cero (DE PSD a HTML5, Bootstrap 4)
# Done 720/1125
# ???1???????????????????Android???????
# Done 721/1125
# Curso de Angular JS
# Done 722/1125
# JAVA Essencial
# Done 723/1125
# Oracle pl/sql procedures functions triggers Forms Reports
# Done 724/1125
# Aprende Programación en C desde cero
# Done 725/1125
# Corso Symfony 3 - Il Framework PHP
# Done 726/1125
# Let’s code Android! – Apps entwickeln mit Android Studio
# Done 727/1125
# Einstieg in C++: Das Praxis-Training
# Done 728/1125
# PHP Experts - Completo e Passo a Passo
# Done 729/1125
# jQuery Giri?
# Done 730/1125
# Yeni Ba?layanlar ?çin Web Tasar?m E?itimi: Adobe Photoshop
# Done 731/1125
# Java para Web IV MVC Design Pattern Factory DAO
# Done 732/1125
# SQL Server Database Administrator (DBA)
# Done 733/1125
# E-Commerce Project with Laravel 5.2.*  from scratch
# Done 734/1125
# Instalando Ruby
# Done 735/1125
# Création de jeux multijoueurs avec Unity 5
# Done 736/1125
# Programmieren mit Visual C# – Das umfassende Training
# Done 737/1125
# Curso Completo de Sites Responsivos
# Done 738/1125
# Programmieren lernen mit Swift
# Done 739/1125
# Java p/ Web II - JSP JavaBeans Servlet Design Pattern DAO
# Done 740/1125
# Diseño de páginas web con HTML5 y CSS3 para novatos
# Done 741/1125
# HTML & CSS: Eigene Webseiten erstellen
# Done 742/1125
# Curso de JavaScript + jQuery + Ajax
# Done 743/1125
# Curso de Microsoft Power BI para principiantes
# Done 744/1125
# NodeJS, Test Unit Mocha, HapiJS, Proxy NGINX,100% práctico
# Done 745/1125
# Arduino I - Crie Projetos Fantásticos
# Done 746/1125
# FileMaker Pro 14 ????????
# Done 747/1125
# Juegos Móviles con HTML5 - Juego Educativo
# Done 748/1125
# Bootstrap ?? ???????
# Done 749/1125
# Joomla! 3 - Das umfassende Training - aktuell zu Joomla! 3.4
# Done 750/1125
# iPhone ??????? - ???????App??????
# Done 751/1125
# Creando juegos con Swift  - Parte 1
# Done 752/1125
# Sistema de Estoque com Delphi
# Done 753/1125
# Javascript per principianti
# Done 754/1125
# WordPress Administración de sitios web
# Done 755/1125
# Creando Un Prototipo Web Móvil Con Ratchet
# Done 756/1125
# django????????????
# Done 757/1125
# La formation complète du développeur PHP 7  MySQL 5
# Done 758/1125
# Programmazione per non programmatori
# Done 759/1125
# GWT-Google Web Toolkit em 107 videoaulas
# Done 760/1125
# Twitter Ads: Multiplica las descargas de tu app con Twitter
# Done 761/1125
# Crea tus temas de Wordpress desde cero y sin programar
# Done 762/1125
# Curso - Desenvolvendo Aplicativos Para Android Nativo
# Done 763/1125
# HTML5 y CSS3 para principiantes: la guía definitiva
# Done 764/1125
# Android II Banco de dados Servidor usando php e java
# Done 765/1125
# Introdução à Lógica de Programação
# Done 766/1125
# ????? C ????? ??  [From 0 to 1: C Programming - Drill Deep]
# Done 767/1125
# Let’s code Minecraft! – Programmieren lernen mit Minecraft
# Done 768/1125
# Unity: ??? ??????? ???? ????? ???????????????? ??? ?? C#
# Done 769/1125
# Python pour débuter en programmation et devenir expert
# Done 770/1125
# jQuery Ö?reniyorum - 1
# Done 771/1125
# Criação de sites com wordpress, sahifa, amazon, woocommerce
# Done 772/1125
# Joomla - Crie Sites Completos de Forma Simples e Rápida
# Done 773/1125
# Aprende expresiones lambda con Java 8 fácilmente.
# Done 774/1125
# Aprende a crear SITIOS WEB con PHP y MySql
# Done 775/1125
# ? WordPress ??????????
# Done 776/1125
# Taller de ANDROID. Leer ficheros XML de un servidor remoto
# Done 777/1125
# 1ste App ohne Erfahrung/Kenntnisse in 20 Tagen machen lassen
# Done 778/1125
# Actionscript 3 Temel ve Nesne Yönelimli Programlama
# Done 779/1125
# Aprende a crear Landing Pages con Bootstrap 3 o Instapage
# Done 780/1125
# Delphi IV - Sistema completo para Gerenciamento de Cursos
# Done 781/1125
# Swift 2 ile Programlama Ö?reniyorum
# Done 782/1125
# Swift 3 ???????
# Done 783/1125
# Apps entwickeln für Android 5 – Das umfassende Training
# Done 784/1125
# Curso Completo de Dreamweaver CC
# Done 785/1125
# Swift3 ??????
# Done 786/1125
# Técnicas de Engajamento em Games
# Done 787/1125
# JAVA: Introducción, conceptos y ejemplos desde cero
# Done 788/1125
# jQuery Ö?reniyorum - 2
# Done 789/1125
# C# ile OOP Giri?
# Done 790/1125
# ????????????07 ?????????????
# Done 791/1125
# Prestashop 1.6 en ESPAÑOL: Tu negocio online
# Done 792/1125
# ?????? Android 6.0 Marshmallow ????????Android Studio???
# Done 793/1125
# Java a través de ejemplos: Una agenda de contactos
# Done 794/1125
# Programar em C usando o Code Blocks
# Done 795/1125
# Apprenez à développer des applications iOS professionnelles
# Done 796/1125
# Kendi TV Kanal?n? Olu?turman?n Temelleri
# Done 797/1125
# Java 8 in der Praxis
# Done 798/1125
# PHP, MYSQL e BOOTSTRAP4 : Crea un sito web dinamico da zero
# Done 799/1125
# Introdução ao Game Design Document (GDD)
# Done 800/1125
# Juegos Móviles con HTML5 - Veggies vs Zombies
# Done 801/1125
# Introduction to PHP In Arabic
# Done 802/1125
# Wordpress 4 dalle basi alle tecniche avanzate
# Done 803/1125
# Swift 2.x / Swift 3.0
# Done 804/1125
# Responsive Web Design - Il Corso Completo
# Done 805/1125
# ?????! ???!
# Done 806/1125
# Corso php per principianti
# Done 807/1125
# Crear Apps para Apple Watch. WatchKit de 0 a 100
# Done 808/1125
# Apprendre ruby
# Done 809/1125
# ?? ?? ???? ?? ??
# Done 810/1125
# Aprende a crear una Template WORDPRESS desde cero
# Done 811/1125
# Aprender a programar en C# Sharp  .NET
# Done 812/1125
# ?????????? ??????? ? ???????? ????? ? ????????? ??????????
# Done 813/1125
# Iníciate en Creación Web con Wordpress
# Done 814/1125
# Criando Temas Customizados com WordPress
# Done 815/1125
# Adicione Push Notifications aos seus Apps iOS (Português)
# Done 816/1125
# Aprende a maquetar: HTML & CSS
# Done 817/1125
# TDD Para Programadores PHP
# Done 818/1125
# ??Google???????????????(Facebook)????
# Done 819/1125
# Curso de MySQL com Banco de Dados
# Done 820/1125
# Drupal 8: Per principianti
# Done 821/1125
# HTML5, CSS3 y Javascript
# Done 822/1125
# Desarrollo web para NO programadores
# Done 823/1125
# Php Olvidate de Hola Mundo Ya
# Done 824/1125
# Créer une boutique en ligne avec Prestashop
# Done 825/1125
# Flex com PHP em 115 videoaulas
# Done 826/1125
# jQuery Essencial
# Done 827/1125
# C#, TFS, Entity Framework ve DevExpress ile CRM Uygulamas?
# Done 828/1125
# Desarrollo de Apps en Android Studio
# Done 829/1125
# Aprende Android desde cero - Curso Completo
# Done 830/1125
# Python Acelerado
# Done 831/1125
# Adobe Flash ile Oyun Programlamaya Ba?lang?ç
# Done 832/1125
# NodeJS fondamentaux
# Done 833/1125
# SAP ABAP Dynamische Programmierung
# Done 834/1125
# Swift vs Objetive-C: Iniciación Al Desarrollo De Apps En iOs
# Done 835/1125
# Dein Wordpress Blog als native App im Google Play Store
# Done 836/1125
# Matematika 1 >> Riješeni ispiti. Položi ispit iz prve
# Done 837/1125
# Android IV em 74 videoaulas
# Done 838/1125
# Manual infalible para ser elegid@ en entrevista de trabajo
# Done 839/1125
# Introducción a Android Lollipop
# Done 840/1125
# E-Commerce completo Flex c/ PHP e pagseguro
# Done 841/1125
# Impara il linguaggio html da zero
# Done 842/1125
# PHP O.O. Loja Virtual, Adodb em 163 videoaulas
# Done 843/1125
# Crie seu Proprio Website: Front End
# Done 844/1125
# Erstellen einer hybriden App mit dem Salesforce Mobile SDK
# Done 845/1125
# Desarrollo de Juegos para Facebook, de novato a experto
# Done 846/1125
# Introdução à Programação Orientada a Objetos
# Done 847/1125
# ????????JavaScript?jQuery?????? ???????????????????????????
# Done 848/1125
# Aprenda a Gerador de Formulários (CRUD) rápidos em Java
# Done 849/1125
# ??? ?????? ?? ??? ???? ????
# Done 850/1125
# Delphi ile Android ve IOS Programlama 1
# Done 851/1125
# Aprenda tudo sobre HTML5
# Done 852/1125
# Lidera y coordina la creación de un sitio web
# Done 853/1125
# Maquetacion web con frameworks
# Done 854/1125
# Técnico en Creación Web y Blog con WordPress
# Done 855/1125
# Visitors Counter Online php & mysqli & jquery (Arabic)
# Done 856/1125
# Wordpress - Crie um Site Profissional em Um Dia com Pugs
# Done 857/1125
# HTML5 CSS3 & responsive design : formation professionnelle
# Done 858/1125
# Yaz?l?mc?lar ve Web Geli?tiriciler ?çin HTML
# Done 859/1125
# Programación Android 04 Ciclo de vida de una actividad
# Done 860/1125
# Programación Android 02 Lo necesario para empezar
# Done 861/1125
# ???? ????? ?????? ??????? ? ??????? ???????
# Done 862/1125
# CSS ile Tasar?ma Giris
# Done 863/1125
# Django Framework Dersleri
# Done 864/1125
# Aprende a programar de una vez por todas
# Done 865/1125
# Creare una landing page
# Done 866/1125
# Curso Completo de CSS3
# Done 867/1125
# Node.js  socket.io ve redis kullanarak real-time chat örne?i
# Done 868/1125
# Curso completo de criação de aplicativos em Swift 2, IOS9
# Done 869/1125
# Fundamentals of Joomla Arabic ???? ?????! ????????
# Done 870/1125
# Estendi la potenza di Joomla con K2
# Done 871/1125
# Mobile II iOs e Android com Delphi
# Done 872/1125
# Refactorizar para mejorar la calidad del código Java
# Done 873/1125
# Aprende a programar juegos sencillos con Scratch para niños
# Done 874/1125
# Impara CodeIgniter in 5 Giorni: Framework PHP MVC (Italiano)
# Done 875/1125
# Introducción al ArcGIS
# Done 876/1125
# Aprende y entiende java ahora
# Done 877/1125
# Spring Framework con Java: Aprende de forma definitiva.
# Done 878/1125
# ?????? ??????? ?????? ????? ????? ??????? ????????
# Done 879/1125
# Swift ile Türkçe iPad iPhone Programlama Görsel E?itim Seti
# Done 880/1125
# PhoneGap für Einsteiger
# Done 881/1125
# HTML javascript css - crie páginas para internet
# Done 882/1125
# Java SE II
# Done 883/1125
# ???JavaScript & ??????? with ?????????????
# Done 884/1125
# C ve C++ ile Programlamaya Giri?: Visual Studio ile 43 Örnek
# Done 885/1125
# jQuery Ö?reniyorum - 3 (Son)
# Done 886/1125
# Curso Completo de Java – con Teoría, Ejercicios y Soluciones
# Done 887/1125
# CSS ? JavaScript ? ??? ?? ??? ????
# Done 888/1125
# Ionic 2 For Beginners (In Arabic)
# Done 889/1125
# Créer une Application de gestion de caisse avec Access 2013
# Done 890/1125
# WordPress Experte werden
# Done 891/1125
# Créer un Portfolio pro avec koken : The photographer guide
# Done 892/1125
# Joomla 3 Giri?
# Done 893/1125
# Crie Widgets para Apps iOS
# Done 894/1125
# Moderne Webseiten entwickeln – Das umfassende Training
# Done 895/1125
# Reportes Oracle APEX
# Done 896/1125
# ????????PHP?MySQL | ???WEB???????????????????????????????
# Done 897/1125
# 3d GameStudio crie jogos fantásticos em 100 videoaulas
# Done 898/1125
# Aprenda Lógica de Programação
# Done 899/1125
# S?f?rdan Git Kullan?m? : Versiyon Kontrolünün Gücü
# Done 900/1125
# Como Identificar e Fidelizar Diferentes Tipos de Jogadores
# Done 901/1125
# ?????Wordpress?????????
# Done 902/1125
# Raspberry Pi: Das eigene Blog mit WordPress 4.0
# Done 903/1125
# 10 projetos de iBeacon - IoT (Internet of Things)
# Done 904/1125
# django?????????????????
# Done 905/1125
# Desarrolla Tus Juegos En iOs y Android, Sin Programar Nada!
# Done 906/1125
# Criando blog com Bootstrap
# Done 907/1125
# Visual Studio ile Windows 8 Uygulamalar?na Ba?lang?ç
# Done 908/1125
# diseño web con muse
# Done 909/1125
# jQuery: Das Praxis-Training
# Done 910/1125
# ???? ?? ?????? ? ???? ?? ????????
# Done 911/1125
# JQuery Mobile ile Mobil Uygulamalar?n?z? Geli?tirin
# Done 912/1125
# Curso Adobe Flex 3.0 e Flex 4.5
# Done 913/1125
# Loja Virtual com PHP e Banco de Dados Avançado
# Done 914/1125
# Oracle SQL' e giri?
# Done 915/1125
# ????????????Android?????????????????????Marshmallow???
# Done 916/1125
# Aprenda a Criar Sites com o Adobe Muse
# Done 917/1125
# Créer un site Web dynamique de A à Z avec PHP
# Done 918/1125
# Einstieg in Java – Der einfache Weg zum Java-Programmierer
# Done 919/1125
# C# Orientação a Objetos - Avançado - K31
# Done 920/1125
# Hybrid Uygulama E?itimi - Cordova
# Done 921/1125
# Delphi II  Avançado - 22 horas de gravação em 160 videoaulas
# Done 922/1125
# Java - Il linguaggio
# Done 923/1125
# Flexible Boxes – Eine Einführung in moderne Websites
# Done 924/1125
# Crea sitios web  fácil en Dreamweaver y bootstrap desde cero
# Done 925/1125
# Diseño de Webs 2.0 con Joomla para novatos
# Done 926/1125
# Découverte de Symfony 2
# Done 927/1125
# Object Oriented Programming in C++
# Done 928/1125
# Productiviteit met WebStorm
# Done 929/1125
# Spring Framework em 125 videoaulas IoC Dependency Injection
# Done 930/1125
# Orientação a Objetos em Java - Introdução - K11
# Done 931/1125
# Implemente Compras In App e Ganhe Dinheiro com App Freemium
# Done 932/1125
# PHP7: Programmazione orientata agli oggetti.
# Done 933/1125
# Curso Completo do framework Hibernate em 178 videoaulas
# Done 934/1125
# Java para Web III - JTSL, EL e Custom Tags
# Done 935/1125
# MegaCurso PHP
# Done 936/1125
# ASP NET COM c# em mais de 100 videoaulas
# Done 937/1125
# android App ???? ????? ??????? ? ???? ?? ????? ??? ????????
# Done 938/1125
# Webdev - Criando aplicações para Web
# Done 939/1125
# Création d'applications mobiles pour débutants sur Android
# Done 940/1125
# Curso I Mobile IOS  e Android c/ Delphi
# Done 941/1125
# Visual Basic: Conviértete en un Experto de Programacion
# Done 942/1125
# Instalação e Gerência de lojas virtuais com Magento
# Done 943/1125
# ????? HTML ? CSS ????
# Done 944/1125
# Apprendre Bootstrap et créer un CV en ligne responsive
# Done 945/1125
# Como ganar dinero con apps de android sin programar
# Done 946/1125
# Learn iOS in Arabic
# Done 947/1125
# Aprende a generar compras y anuncios en tus Apps para iOS
# Done 948/1125
# Ruby on Rails dla pocz?tkuj?cych
# Done 949/1125
# Asp.Net C# Web Programlama Dersleri
# Done 950/1125
# eCommerce - Erstelle deinen eigenen Online-Shop
# Done 951/1125
# Créer un site e-commerce avec Wordpress
# Done 952/1125
# La réalité virtuelle avec Unity 5 & C#
# Done 953/1125
# Créer un site web de commerce en ligne
# Done 954/1125
# Criação de lojas virtuais com WordPress WooCommerce
# Done 955/1125
# 15 giorni con Prestashop vol.1 - per principianti
# Done 956/1125
# Criar Site Profissional Sem Programação
# Done 957/1125
# Créer des sites responsives avec jQuery mobile
# Done 958/1125
# Técnicas de Storytelling e Narrativas em Games
# Done 959/1125
# IOS10??/Swift3.0????????IPhoneApp????/????/??????
# Done 960/1125
# Curso de JavaScript Completo
# Done 961/1125
# Apple Watch?????????????????????????????? swift 2.0 os1/2
# Done 962/1125
# C Programlama Dili
# Done 963/1125
# Proyectos Web profesionales con Ruby y Ruby OnRails
# Done 964/1125
# Android III avançado Mapas GPS Notificações
# Done 965/1125
# Curso de Android com Mysql
# Done 966/1125
# Kendi Eticaret Siteni Geli?tir K?s?m 3-4
# Done 967/1125
# TYPO3 CMS 6 – Das umfassende Training
# Done 968/1125
# Corso base di jQuery
# Done 969/1125
# Flex com Java - crie sistemas ricos para web
# Done 970/1125
# Kendi Eticaret Siteni Geli?tir K?s?m 5-6
# Done 971/1125
# AIR ile Android Uygulamalar? Geli?tirmek
# Done 972/1125
# Sistema WEB com ASP.NET
# Done 973/1125
# Crea un Sitio Web de Avisos Clasificados, Sin Programar!
# Done 974/1125
# ????? C#?????????????
# Done 975/1125
# Delphi III - Super Avançado Biometria POO etc
# Done 976/1125
# Crea Sito + Ecommerce Joomla/WP sfruttando Servizi Gratuiti
# Done 977/1125
# XML Giri?
# Done 978/1125
# Desarrolla tu primer juego con Python en Español
# Done 979/1125
# Python?Django????????????????
# Done 980/1125
# Programación con PHP y MySQL
# Done 981/1125
# ???? ??????? ???? ?? ??? ???
# Done 982/1125
# Swift 2 de Padawan a Maestro Jedi
# Done 983/1125
# Virtuemart loja virtual (e-commerce) com joomla
# Done 984/1125
# Python, django, Bootstrap??????????????????????
# Done 985/1125
# Taller de PHP: Subir documentos y manipular imágenes
# Done 986/1125
# Curso de Node JS
# Done 987/1125
# Swift basico. Programación para aplicaciones iPhone
# Done 988/1125
# Créer une API avec PHP
# Done 989/1125
# ???????? ???? "????? ????" ? ??????? Unity 5
# Done 990/1125
# Aprende a crear un juego como Candy Crush para iPhone
# Done 991/1125
# Plataforma de ensino a distância com Dokeos
# Done 992/1125
# ???? ????? ??????? ?????????
# Done 993/1125
# Uygulamal? Php Kursu
# Done 994/1125
# JME II - crie aplicações para celular usando Java
# Done 995/1125
# Desarrollando Clon de Flappy Bird y Mas Con Pygame
# Done 996/1125
# Kendi Stok Yönetim Sistemini Geli?tir K?s?m 3
# Done 997/1125
# Python, django, Bootstrap???????????????? ?Vol2. Python??
# Done 998/1125
# Kendi Stok Yönetim Sistemini Geli?tir K?s?m 2
# Done 999/1125
# Desarrollando Juego con Pygame 3.4 y Python
# Done 1000/1125
# Estudando Arrays, Strings e Data no Java
# Done 1001/1125
# Kendi Eticaret Siteni Geli?tir K?s?m 33-34
# Done 1002/1125
# Java 8 Streams De Novato A Experto en Tiempo Récord
# Done 1003/1125
# iOS Unity para videojuegos. Nivel Básico
# Done 1004/1125
# VB .Net: Utilização da Classe PrinterSettings
# Done 1005/1125
# Fundamentos de Ext JS
# Done 1006/1125
# Hébergement, noms de domaine et mettre un site en ligne
# Done 1007/1125
# ????? ??????? ?????? ???????  swift 3-2.x ios9-10 (2 apps)
# Done 1008/1125
# Impara i fondamentali del css
# Done 1009/1125
# Orientação a Objetos em Java - Avançado - K11
# Done 1010/1125
# Criação de lojas virtuais com Opencart - Loja de camisetas
# Done 1011/1125
# Learn HTML & CSS
# Done 1012/1125
# Aprende PHP desde cero y sin conocimientos previos
# Done 1013/1125
# Desenvolvendo web sites responsivos
# Done 1014/1125
# Programmieren lernen - Band 1 (Prozedural)
# Done 1015/1125
# WordPress: ??????????????? ???????? ?????? ?????/?????
# Done 1016/1125
# Padrão de Projetos com C# Volume 1 (Design Patterns)
# Done 1017/1125
# WordPress E-Commerce with WooCommerce in Urdu / Hindi
# Done 1018/1125
# Top-BOSS???????????-???????
# Done 1019/1125
# Web Tasar?m Dünyas?na Merhaba : Html5 & CSS
# Done 1020/1125
# Top-BOSS???????????-??????
# Done 1021/1125
# ????????????????????????? - (Adtech Tokyo 2012 B-6)
# Done 1022/1125
# Instala y configura Mysql, Oracle, SqlServer y PostgreSQL
# Done 1023/1125
# Learn how to make a website without coding and investment
# Done 1024/1125
# ???????????PHP????
# Done 1025/1125
# Wordpress for beginner - Step by Step
# Done 1026/1125
# ????????????????????????????????????????
# Done 1027/1125
# ATDD ??????? ??????? ??????????? ????????
# Done 1028/1125
# Como Criar Blogs Profissionais no Blogger
# Done 1029/1125
# Crea un sitio web desde cero con HTML y CSS  (psd a html)
# Done 1030/1125
# Todo sobre HTML5: semántica y nuevos elementos
# Done 1031/1125
# Aprende Origami paso a paso y aplícalo a tus iPhone apps
# Done 1032/1125
# Crear un Sistema de Facturacion Con Visual Studio
# Done 1033/1125
# Automatische Dokumentation mit DOCCEN - Der Videokurs + Tool
# Done 1034/1125
# ??? ???? ???? ???????? ???? ?????
# Done 1035/1125
# Introducción a HTML
# Done 1036/1125
# Visual Basic Grundlagen
# Done 1037/1125
# Criando site de Imobiliária com WordPress
# Done 1038/1125
# Java Fundamental
# Done 1039/1125
# A linguagem HTML
# Done 1040/1125
# Aplicaciones Tienda Windows: Crear un Lector de Blogs
# Done 1041/1125
# Como Crear un blog Usando Zurb Foundation - HTML5
# Done 1042/1125
# Perl programing language From Beginner To Expert
# Done 1043/1125
# Mejora y completa las funciones de tu página web
# Done 1044/1125
# ?????Drupal???
# Done 1045/1125
# SEO????? (????)
# Done 1046/1125
# ????? ????????
# Done 1047/1125
# Aprendiendo Phone Gap
# Done 1048/1125
# Less CSS
# Done 1049/1125
# Curso Completo: Desarrollo Responsive + Proyectos Prácticos
# Done 1050/1125
# WordPress ????? ?????? ??????? ????????
# Done 1051/1125
# ???? ??????? ?? ??? ???? ???? c#
# Done 1052/1125
# Hébergement, noms de domaine et mettre un site en ligne
# Done 1053/1125
# Aprende Swift y SpriteKit con el juego piedra papel o tijera
# Done 1054/1125
# ???? ?????? ????? ??????? ???? ??? ???? swift
# Done 1055/1125
# Unit Test Yazma Sanat?
# Done 1056/1125
# Android Temel ve Fragment E?itim Seti Türkçe
# Done 1057/1125
# Sistemas de informações geográficas para concursos
# Done 1058/1125
# Html ve css kullanarak tumblr temas? nas?l yap?l?r ?
# Done 1059/1125
# Swift?iMessage Clone???????????????????????
# Done 1060/1125
# ????????????04 ??????????????
# Done 1061/1125
# Introduction To SQL Server Database Administration
# Done 1062/1125
# (Grant Writing) ????? ??????? ?????
# Done 1063/1125
# 0. Apple Watch: Introducción para principiantes
# Done 1064/1125
# Entity Framework Data Model ile Dinamik Asp.net Uygulamalar?
# Done 1065/1125
# L?p trình Lua t? A ??n Z cho Beginners
# Done 1066/1125
# desarrollo web desde cero
# Done 1067/1125
# Tiendas virtuales con joomla
# Done 1068/1125
# iOS Unity para videojuegos. Nivel Avanzado
# Done 1069/1125
# Aprende a desarrollar una aplicación para Apple Watch
# Done 1070/1125
# Introducción a Unity
# Done 1071/1125
# ??????
# Done 1072/1125
# Programación Android 03 Crear la aplicación ¡Hola, mundo!
# Done 1073/1125
# ???Facebook??????????
# Done 1074/1125
# Learn to Unity 3d and C#
# Done 1075/1125
# Desarrollo web estructurado
# Done 1076/1125
# Wordpress ?le Basit Blog Temas? Yap?m?
# Done 1077/1125
# ??? ?????? ??????????? ?? ????????????? ? IT?
# Done 1078/1125
# Aplicaciones universales y adaptación de pantallas iOS
# Done 1079/1125
# Curso Criando sites de compras coletivas
# Done 1080/1125
# Drupal Commerce de A a Z
# Done 1081/1125
# Introducción a UDK
# Done 1082/1125
# HTML 5 + CSS 3
# Done 1083/1125
# ActionScript 3
# Done 1084/1125
# iOS para Apps
# Done 1085/1125
# Lógica de Programação em Java - K01
# Done 1086/1125
# Editor Wysiwyg - Curso de Instalação CKEditor e CkFinder
# Done 1087/1125
# Iníciate en IOS con tu iPad/iPhone
# Done 1088/1125
# Curso de HTML Para Iniciantes
# Done 1089/1125
# Core Java. Exceptions
# Done 1090/1125
# Construa seu site com Joomla
# Done 1091/1125
# Aprende a montar tu blog o negocio desde cero con WordPress
# Done 1092/1125
# WordPress Esencial: Diseño y Desarrollo.
# Done 1093/1125
# Introducción a CSS
# Done 1094/1125
# Windows 10 Universal App Development
# Done 1095/1125
# Magnovus Theme Premium para WordPress
# Done 1096/1125
# Curso completo de Joomla 3.0.X
# Done 1097/1125
# Experto en HTML5: Apréndelo desde cero y a fondo
# Done 1098/1125
# Acessando Banco de Dados com C# e ODBC
# Done 1099/1125
# Orientação a Objetos em Java - Intermediário - K11
# Done 1100/1125
# Fundamentos de Base de Datos para Principiantes
# Done 1101/1125
# Cours Complet iOS10 & Swift 3 -  Créez 15 applications
# Done 1102/1125
# Corso MongoDB: basi del database no-sql più usato al mondo
# Done 1103/1125
# JQuery Mobile - Yeni Ba?layanlar ?çin
# Done 1104/1125
# Impara le basi di JavaScript
# Done 1105/1125
# Objective-C Programlama Dili
# Done 1106/1125
# Programación CNC - Fresadoras
# Done 1107/1125
# Introducción a Apache OpenOffice 4.0
# Done 1108/1125
# Integrações Gerencianet Pagamentos
# Done 1109/1125
# ???????????????
# Done 1110/1125
# Apprendi le basi di HTML e CSS
# Done 1111/1125
# iOS 9 und Swift 2.0 Einsteiger Kurs
# Done 1112/1125
# Impara tecniche avanzate di CSS
# Done 1113/1125
# Let's Code AntMe!
# Done 1114/1125
# Creación de un videojuego completo con adobe flash
# Done 1115/1125
# WordPress for Beginners to Advance in Urdu / Hindi
# Done 1116/1125
# Top-BOSS???????????-???/??/????
# Done 1117/1125
# ?????????????????? (Adtech Tokyo 2013 Track B-4)
# Done 1118/1125
# ?????Node.js????
# Done 1119/1125
# ???? ???? ??????
# Done 1120/1125
# ????? ???? ???? ?? ???? Ruby on Rails
# Done 1121/1125
# jquerymobile ? ??? image ????? ???
# Done 1122/1125
# ???????? ????? ?? Wordpress ??? ??????????
# Done 1123/1125
# Top-BOSS???????????-???????
# Done 1124/1125
# Adobe Flash ActionScript 3 Ba?lang?ç E?itimi
# Done 1125/1125

# %%
save_course_data(get_udemy_curriculum("machine-learning-com-weka-e-java"))

# %%
def get_udemy_curriculum_deprecated(page):
    #Get page html object
    full_page = "https://www.udemy.com/" + page
    html = requests.get(full_page, timeout=60).text
    soup = BeautifulSoup(html, 'html.parser')
    
    data-course-id
    
    
    
    #Get page title
    curriculum = dict()
    title = soup.find("h1", {"class":"clp-lead__title"})
    if not title:
        raise Exception("Title not found")
    curriculum["title"] = title.get_text().strip()
    
    
    
    #Get curriculum data
    curriculum["children"] = list()
    curriculum_wrapper = soup.find("div", {"class": "curriculum-wrapper"})
    for content_container in curriculum_wrapper.find_all("div", {"class": "content-container"}):
        content_title_tag = content_container.find("span", {"class":"lecture-title-text"})
        if content_title_tag == None:
            continue
        content_title = content_title_tag.get_text().strip()
        content_children = list()
        
        for lecture_container in content_container.find_all("div", {"class":"lecture-container"}):
            content_child_title = lecture_container.find("div", {"class":"title"}).get_text().strip()
            content_children.append({"title":content_child_title})
        
        curriculum["children"].append({
            "title":content_title,
            "children": content_children
        })
    
    return curriculum

# %%
course_data = get_udemy_curriculum("machine-learning-com-weka-e-java")

# %%
print(course_data["title"])
for child in course_data["children"]:
    print("      " + child["title"])
    for child_2 in child["children"]:
        print("            " + child_2["title"])
# Out:
# Machine Learning com Weka e Java
#       Boas-vindas
#             Boas-vindas
#       Aprendizagem de máquina
#             Introdução
#             O que é aprendizagem de máquina
#             Métodos preditivos
#             Métodos descritivos I
#             Métodos descritivos II
#             Tipos de aprendizagem de máquina
#             Classificação I
#             Classificação II
#             Extração de características I
#             Extração de características II
#             Extração de características III
#             Reconhecimento dos personagens
#             Seleção de características dos personagens
#       Extrator de características
#             Introdução
#             Download das ferramentas
#             Entendendo a extração das cores
#             Instalação do projeto dos personagens
#             Código fonte do extrator de características I
#             Código fonte do extrator de características II
#             Código fonte do extrator de características III
#             Arquivo ARFF dos personagens
#             Carregando a imagem
#             Extração das características da imagem selecionada
#             Testando a extração das características
#             Base de dados para análise
#             Código fonte parcial
#       Introdução ao Weka
#             Introdução
#             Instalação do Weka
#             Introdução ao Weka
#             Entendendo os valores da janela inicial do Weka
#             Arquivos ARFF
#       Aprendizagem bayesiana
#             Introdução
#             Naive Bayes I
#             Naive Bayes II
#             Naive Bayes III
#             Naive Bayes IV
#             Naive Bayes no Weka
#             Carregando o ARFF dos personagens no Java
#             Classificando os personagens com o Naive Bayes
#             Código fonte parcial
#       Aprendizagem por árvores de decisão
#             Introdução
#       Aprendizagem por regras
#             Introdução
#       Aprendizagem baseada em instâncias
#             Introdução
#       Aprendizagem de redes neurais artificiais
#             Introdução
#       Aprendizagem de máquinas de vetores de suporte
#             Introdução
#       Outros algoritmos
#             Introdução
#       Avaliação dos algoritmos
#             Introdução
#       Combinação e rejeição de classificadores
#             Introdução
#       Considerações finais
#             Introdução
#             Saber mais sobre Inteligência Artificial
#             Cupons de desconto

# %%
html = download_page("https://www.udemy.com/data-science-deep-learning-in-theano-tensorflow/")

# %%
curriculum_wrapper = soup.find_all("div", {"class": "curriculum-wrapper"})

# %%
content_container = soup.find_all("div", {"class": "content-container"})

# %%
for content in content_container:
    print(content.find("span", {"class":"lecture-title-text"}).get_text())
# Out:
# Outline, the MNIST dataset, and Linear (Logistic Regression) Benchmark
# Gradient Descent: Full vs Batch vs Stochastic
# Momentum and adaptive learning rates
# Choosing Hyperparameters
# Theano
# TensorFlow
# Modern Regularization Techniques
# GPU Speedup, Homework, and Other Misc Topics
# Project: Facial Expression Recognition
# Appendix
