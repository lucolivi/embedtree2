# %%
from bs4 import BeautifulSoup
import requests
import json

# %%
import csv
def get_courses_data(filename):
    course_data = list()
    with open(filename, newline='', encoding='utf-8') as csvfile:
        spamreader = csv.reader(csvfile)
        return list(spamreader)
    
#get_courses_data("udemy_dev.csv")

# %%
def get_udemy_course_data(page):
    #Get page html object
    full_page = "https://www.udemy.com/" + page
    html = requests.get(full_page, timeout=60).text
    soup = BeautifulSoup(html, 'html.parser')
    
    course_title = soup.find("h1", {"class":"clp-lead__title"}).get_text().strip()
    course_id = soup.find("div", {"data-course-id":True})["data-course-id"]
    
    return course_title, course_id
    
#get_udemy_course_data("data-science-deep-learning-in-python")

# %%
def get_udemy_curriculum_by_id(courseid):
    full_page = "https://www.udemy.com/api-2.0/courses/" + courseid + "/public-curriculum-sections"
    curriculum_data = requests.get(full_page, timeout=60).json()
    
    curriculum = list()
    
    for content in curriculum_data['results']:
        content_title = content['title']
        content_subtitles = [{"t": subcont['title']} for subcont in content["items"]]
        
        curriculum.append({"t":content_title, "c":content_subtitles})
    
    return curriculum
    
#get_udemy_curriculum_by_id('364426')

# %%
def get_udemy_curriculum(page):
    course_title, course_id = get_udemy_course_data(page)
    curriculum = get_udemy_curriculum_by_id(course_id)
    
    return {"t":course_title, "i":course_id, "c": curriculum}

#c = get_udemy_curriculum("machine-learning-na-pratica")
#print(c)

# %%
def save_course_data(course_data):
    json_string = json.dumps(course_data)
    filename = "".join(["udemy_data/",course_data['i'],".json"])
    f = open(filename, 'w')
    f.write(json_string)
    f.close()
#save_course_data(get_udemy_curriculum("machine-learning-com-weka-e-java"))

# %%
courses_data = get_courses_data("udemy_acad.csv")
list_size = len(courses_data)

for i, (course_id, course_title) in enumerate(courses_data):
    print(course_title)
    try:
        curriculum = get_udemy_curriculum_by_id(course_id)
        save_course_data({"t":course_title, "i":course_id, "c": curriculum})
    except:
        pass
    print("Done {}/{}".format(i+1, list_size))
# Out:
# Critical Thinker Academy: Learn to Think Like a Philosopher
# Done 1/1017
# Workshop in Probability and Statistics
# Done 2/1017
# Deep Learning Prerequisites: Logistic Regression in Python
# Done 3/1017
# The Inexplicable Universe with Neil deGrasse Tyson
# Done 4/1017
# How to Make a Difference by Nicholas Kristof & Sheryl WuDunn
# Done 5/1017
# Deep Learning Prerequisites: Linear Regression in Python
# Done 6/1017
# Simply Jesus
# Done 7/1017
# Chinese Made Easy L2: Understand 79% of Chinese in 10 hours
# Done 8/1017
# Paul and His Letter to the Galatians
# Done 9/1017
# Write a Novel Outline from Scratch (Novel Writing Success)
# Done 10/1017
# Become a Trigonometry Master
# Done 11/1017
# Paper Writing: A Procrastinator's Guide
# Done 12/1017
# Structural Equation Modelling using AMOS: With Examples
# Done 13/1017
# A Complete First Course in Differential Equations
# Done 14/1017
# The economic model of emerging countries - Michael Spence
# Done 15/1017
# Algebra for A-Level Maths
# Done 16/1017
# Ultimate guide to Linear Equations
# Done 17/1017
# Introduction to Fallacies: How to spot poor reasoning
# Done 18/1017
# Conquer number systems and their conversions
# Done 19/1017
# Calculus I:   Be Ready For Your College Calculus I Course
# Done 20/1017
# Creative Writing - Writing Tips part 1
# Done 21/1017
# Memorize 50 Elements From The Periodic Table In 30 Minutes
# Done 22/1017
# Economics-Demand and Supply Analysis
# Done 23/1017
# Master Cognitive Biases and Improve Your Critical Thinking
# Done 24/1017
# Learn Probability and Statistics in an easy way
# Done 25/1017
# Paul and His Letter to the Romans: Part Two (Romans 6-11)
# Done 26/1017
# Write: Basic Creative Writing Skills for Beginners (2016 Ed)
# Done 27/1017
# Become a Calculus 1 Master
# Done 28/1017
# Become an Algebra Master
# Done 29/1017
# Analog electronics - Robotics, learn by building
# Done 30/1017
# Paul and His Letter to the Romans: Part One (Romans 1-5)
# Done 31/1017
# Fractal Geometry in Python
# Done 32/1017
# Simply Good News
# Done 33/1017
# Learn to Publish A Research Paper
# Done 34/1017
# Paul and His Letter to the Philippians
# Done 35/1017
# Introductory Psychology -- A Video Textbook
# Done 36/1017
# Quantum Physics: an overview of a weird world
# Done 37/1017
# How to Pass AP Statistics, DSST, College Stats & Probability
# Done 38/1017
# Algebra I (Beginning Algebra)
# Done 39/1017
# Learn Social Psychology
# Done 40/1017
# 24 Days to Multiplication Mastery
# Done 41/1017
# The Neuroscience of Reframing & How to Do It
# Done 42/1017
# PLS Path Modeling with the semPLS and PLSPM Packages in R
# Done 43/1017
# Learn SCADA from Scratch - Design, Program and Interface
# Done 44/1017
# Paul and His Letter to Philemon
# Done 45/1017
# Become an Electricity & Electronics Pro!
# Done 46/1017
# 5 Amazing Psychology Experiments
# Done 47/1017
# Learn Social Psychology Fundamentals
# Done 48/1017
# Tech-Tutor: Mastering Conversion of Number Systems
# Done 49/1017
# Ultimate guide to math word problems - Beginners Part Two
# Done 50/1017
# Bible Study: Philemon - 7 Lessons We Can Learn For Today!
# Done 51/1017
# PLS Path Modeling with the Desktop PLS-GUI Application
# Done 52/1017
# Quran Memorization Course. A proven system to do it easy NOW
# Done 53/1017
# Calculus (Calculus 1; Calculus A; Differential Calculus)
# Done 54/1017
# Structural equation modeling (SEM) with lavaan
# Done 55/1017
# Fundamentals of Ultrasonic Testing: Level 1 Exam Preparation
# Done 56/1017
# Germany 1919-1947
# Done 57/1017
# Backyard Astronomy
# Done 58/1017
# Particle Swarm Optimization in MATLAB
# Done 59/1017
# Experimental Psychology
# Done 60/1017
# Maths - Basic angles, distances and coordinates
# Done 61/1017
# Level 1 Intelligence Analyst Certification
# Done 62/1017
# Decision Science
# Done 63/1017
# Statistics explained easy - Normal Distribution and more
# Done 64/1017
# Linear Algebra Tutorial: Determinants
# Done 65/1017
# Principles of Microeconomics : Elasticity
# Done 66/1017
# Academic Writing: 10 Essential Essays You Should Know
# Done 67/1017
# Become an Egyptologist: Introduction to Ancient Egypt
# Done 68/1017
# 15 Concepts to Know for the Chemistry Regents
# Done 69/1017
# Probability made easy: Learn Bayes Law
# Done 70/1017
# The Art of Bernini
# Done 71/1017
# Ancient Greek Religion
# Done 72/1017
# Master the Fundamentals of Math
# Done 73/1017
# Lectures on Greek History and Culture
# Done 74/1017
# How to Write Better Essays: Improve Your Grades Today!
# Done 75/1017
# Introduction to Human Rights
# Done 76/1017
# Paul and His Letter to the Romans: Part Three
# Done 77/1017
# Mastering Mental Math Tricks - Vedic Mathematics
# Done 78/1017
# How to become a bestselling author on Amazon or Kindle
# Done 79/1017
# Basics of Macroeconomics
# Done 80/1017
# Mastering Basic Math skills
# Done 81/1017
# Ultimate guide to math word problems Intermediate Part Two
# Done 82/1017
# Master 2-Stage Least Squares Without Any Mathematics
# Done 83/1017
# Electrical Engineering Simulations with Etap
# Done 84/1017
# Master Hypothesis Testing
# Done 85/1017
# Polynomial Regression, R, and ggplot
# Done 86/1017
# The Simplest & Easiest Course on Hypothesis Testing
# Done 87/1017
# Punch Them In The Gut: Writing Fiction with Emotional Impact
# Done 88/1017
# Learn Psychology: Why We Think Feel and Act the Way We do
# Done 89/1017
# Fairy Tales: A Quick and Unique Guide to Successful Reading
# Done 90/1017
# Infinite Sequence and Series
# Done 91/1017
# Write Stories With a Twist
# Done 92/1017
# Math is Everywhere: Applications of Finite Math
# Done 93/1017
# Economics: Theory and Applications
# Done 94/1017
# Creative Writing Novel Workshop - Success with Theme
# Done 95/1017
# Vedic Maths: Learn to do calculations upto 10 times faster
# Done 96/1017
# Screenwriting 101 | Your 7-Day Guide to a Killer Movie Idea
# Done 97/1017
# Life of a Pilot's Wife During World War 2
# Done 98/1017
# An Introduction to Philosophy
# Done 99/1017
# Maths the Wacky Way
# Done 100/1017
# School of the Supernatural - Dream Interpretation
# Done 101/1017
# Beginning Algebra: Building a Foundation
# Done 102/1017
# The String theory - Edward Witten
# Done 103/1017
# Composition: Quality Paragraph and Essay Writing
# Done 104/1017
# Righteous Prosperity - Walking in Your Identity in Christ
# Done 105/1017
# Become an Egyptologist: A Comprehensive Look at Tutankhamun
# Done 106/1017
# GCSE Biology AQA B1
# Done 107/1017
# Chemistry 101 - Part 1 Principles of Chemistry
# Done 108/1017
# Creative Writing – Entering Writing Competitions
# Done 109/1017
# Become an Egyptologist: A Comprehensive Look at Ramesses II
# Done 110/1017
# Help Your Students Learn About the Holocaust: 1933-1945
# Done 111/1017
# Get started with Species Distribution Modelling in Maxent
# Done 112/1017
# Overview of Research Tools & Writing a research proposal
# Done 113/1017
# Become a Geometry Master
# Done 114/1017
# Probability made easy: Learn counting techniques
# Done 115/1017
# Clinical Research for Beginners
# Done 116/1017
# Statistics and Zen
# Done 117/1017
# English Legal System in 60 Minutes: A Fast Track Summary
# Done 118/1017
# Probability Made Easy
# Done 119/1017
# Microeconomics : Behavior of Buyers and Sellers
# Done 120/1017
# The USA 1930-2000
# Done 121/1017
# Probability made easy: Continuous randomness
# Done 122/1017
# Finish Your Thesis in Six Months
# Done 123/1017
# Art History Renaissance to 20th Century
# Done 124/1017
# New GCSE/iGCSE Maths Complete Revision - Number
# Done 125/1017
# Fundamentals of Airplane Engineering
# Done 126/1017
# Creative Writing Novel Workshop - Success with Characters
# Done 127/1017
# Maths Functions for Beginners
# Done 128/1017
# Gender Equality and Sexual Diversity
# Done 129/1017
# Linear Mixed-Effects Models with R
# Done 130/1017
# Hacking STEM: Improve your performance in class
# Done 131/1017
# Basics of Microeconomics : Theory of Producer Behaviour
# Done 132/1017
# Chemistry 101 - Part 4 Chemistry in Society
# Done 133/1017
# Basic Electrical Engineering - Secrets Revealed
# Done 134/1017
# Operation Drumbeat: The U-boat War Off America's Coast, 1942
# Done 135/1017
# Non-Parametric Analysis
# Done 136/1017
# Brain Anatomy - Learn biopsychology science quickly & easily
# Done 137/1017
# Transparency and Anti-Corruption
# Done 138/1017
# Hernando Cortes and the Aztec Civilization
# Done 139/1017
# Trigonometry:A Beginner's Guide To High School Students
# Done 140/1017
# American History and Donald Trump
# Done 141/1017
# Linear Algebra for Beginners: Open Doors to Great Careers 2
# Done 142/1017
# Howard Carter And The Search For Tutankhamun
# Done 143/1017
# Multilevel SEM Modeling with xxM
# Done 144/1017
# USLawEssentials Introduction to US Contract Law
# Done 145/1017
# The Complete Psychology Entrance Course
# Done 146/1017
# Understanding the Politics of the United States of America
# Done 147/1017
# Mistakes to Avoid in LAW SCHOOL
# Done 148/1017
# Get Great Learning Skills and Have More Time for Fun!
# Done 149/1017
# Prayer and Evangelism - Impacting Nations & Hurting People
# Done 150/1017
# Foundation of Statistics with Minitab
# Done 151/1017
# What makes healthy bones?
# Done 152/1017
# Become a Human Calculator with Vedic Mathematics
# Done 153/1017
# 8 Must Know Methods for Solving Math Problem Sums
# Done 154/1017
# Learn Hands-on Electronics Step-By-Step: Level-1
# Done 155/1017
# Easy Anatomy and Physiology (Platinum Edition)
# Done 156/1017
# Quick-fire Method of Squaring & Cubing of Numbers up to 100
# Done 157/1017
# Flat Earth Clues
# Done 158/1017
# Learn Neural Networks using Matlab Programming
# Done 159/1017
# Philosophy of Language: Intriguing Puzzles and Paradoxes
# Done 160/1017
# Abacus Math From Scratch
# Done 161/1017
# ABC of Fractions
# Done 162/1017
# ACE the AP Statistics Exam and MASTER Elementary Statistics!
# Done 163/1017
# Geometry
# Done 164/1017
# How To Make Your Child love Math::Vedic addition&subtraction
# Done 165/1017
# Biology for O Level Examinations (CXC, GCSE): Reproduction
# Done 166/1017
# Public Speaking for Kids: Kids Can Be Great Speakers Now!
# Done 167/1017
# Microeconomics - 1: Finding Demand
# Done 168/1017
# Mental Health Disorders in Infancy and Early Childhood
# Done 169/1017
# Ancient Ireland: Culture and Society
# Done 170/1017
# Ministry Essentials - How to Start a Successful Ministry
# Done 171/1017
# Become an Egyptologist: The Basics of Egyptian Mythology
# Done 172/1017
# Discrete Mathematics
# Done 173/1017
# Master Discrete Mathematics: Set Theory
# Done 174/1017
# College Math Essentials: Logarithms
# Done 175/1017
# An Introduction to Data Visualization in R using ggplot
# Done 176/1017
# Weather Prediction 101
# Done 177/1017
# Multiple Regression Step by Step ( A Complete Course )
# Done 178/1017
# Power 9 ISEE Math Middle Level
# Done 179/1017
# Algebra for Beginners
# Done 180/1017
# Bible Study: Philippians - 7 Lessons We Can Learn For Today!
# Done 181/1017
# Napoleon in Egypt
# Done 182/1017
# Global Environmental Problems: Surveying the Human Footprint
# Done 183/1017
# Solve Math Problems With A Computer Using Maple
# Done 184/1017
# Electronics : Zener Diode & Light Emitting Diode
# Done 185/1017
# Art History Prehistory to the Renaissance
# Done 186/1017
# Algebra II (Intermediate Algebra)
# Done 187/1017
# Probability For Beginners : Building a  Foundation
# Done 188/1017
# Random Variables & Probability Distributions
# Done 189/1017
# Statistical Problem Solving in Geography
# Done 190/1017
# Ultimate guide to math word problems - Beginners Part One
# Done 191/1017
# Ace Your Online Class
# Done 192/1017
# Digital Signal Processing with MATLAB (Codes Included)
# Done 193/1017
# Linear Algebra for Beginners: Open Doors to Great Careers
# Done 194/1017
# Easy Anatomy and Physiology
# Done 195/1017
# Introduction to Linguistics
# Done 196/1017
# Matlab keystone skills for Mathematics (Matrices & Arrays)
# Done 197/1017
# Become a Calculus 2 Master
# Done 198/1017
# Economics: How Consumers Take Buying Decisions
# Done 199/1017
# Basics of Statistics - A Comprehensive Study (College Level)
# Done 200/1017
# Writing Short Stories: The Essential Guide
# Done 201/1017
# Data Visualization with MATLAB: The Basics and Beyond
# Done 202/1017
# Become a Manufacturing Pro!
# Done 203/1017
# Fortune Favors the Brave: Ancient Lessons for Modern Success
# Done 204/1017
# Serving Well in China
# Done 205/1017
# My Favorite Universe by Neil deGrasse Tyson
# Done 206/1017
# Calculate faster in Mind: Mastering Math skills
# Done 207/1017
# Worldviews, the Bible, and the Believer
# Done 208/1017
# Become an amazing Math Magician::The secrets of Mental Math
# Done 209/1017
# Understand the Mind: 15 Fascinating Psychology Studies
# Done 210/1017
# Visualize Current,Voltage,Resistance & The Ohm's Law
# Done 211/1017
# Common Core Math Concepts: K-8
# Done 212/1017
# Learn Social Psychology - The Self & Self-Esteem
# Done 213/1017
# Math Brain! Speed Mathematics Skills & Easy Maths Methods
# Done 214/1017
# Hierarchy of the human body
# Done 215/1017
# Algebra Foundation:  Variables & Equations
# Done 216/1017
# Accounting you need to know to be ready for the MBA
# Done 217/1017
# Number Conversion: Convert Binary, Decimal, and Hexadecimal
# Done 218/1017
# Addressing Racial Microaggressions in Our Schools
# Done 219/1017
# Truss Analysis in 7 Easy Steps
# Done 220/1017
# Paraphrasing
# Done 221/1017
# NCERT Solutions for Class 10 Maths Chapter 6 Triangles
# Done 222/1017
# The Geography of Globalization
# Done 223/1017
# You Can Teach Your Child to Read Very Successfully!
# Done 224/1017
# Public Speaking for College Students: Become a Great Speaker
# Done 225/1017
# Basic Hydrology
# Done 226/1017
# Calculus II (Integral Calculus)
# Done 227/1017
# 2 - Concepts of Statistics For Beginner level to advance
# Done 228/1017
# Learn basic high school Maths the easy way!
# Done 229/1017
# Racial Profiling Awareness
# Done 230/1017
# Learn Complete Algebra
# Done 231/1017
# Ultimate guide to Trigonometry
# Done 232/1017
# 2015 Great Decisions: Foreign Policy Association
# Done 233/1017
# Basic Geometry: Language and Labels
# Done 234/1017
# Astronomy - State of the Art
# Done 235/1017
# R, ggplot, and Simple Linear Regression
# Done 236/1017
# Become a Calculus 3 Master
# Done 237/1017
# Research Methods For Business Students
# Done 238/1017
# Fundamentals of Automobile Engineering
# Done 239/1017
# Statistics and Probability - Basics
# Done 240/1017
# 102  -  Water Wise: Evidence for a Worldwide Flood
# Done 241/1017
# 5 Brief Lessons on Biology
# Done 242/1017
# A Brief History of India.
# Done 243/1017
# Cultural Anthropology
# Done 244/1017
# The Road to Becoming a Better Writer
# Done 245/1017
# Mediation, Moderation, and Conditional Process Analysis
# Done 246/1017
# The Spanish Conquistadors in La Florida
# Done 247/1017
# Know how to get  an "A" in your Financial Accounting 101 .
# Done 248/1017
# Introduction to Statistics
# Done 249/1017
# United States History - Prehistory to Reconstruction
# Done 250/1017
# Know how get an "A" in your  Management Accounting 101
# Done 251/1017
# Classics of American Literature: T. S. Eliot
# Done 252/1017
# Statistics / Data Analysis: Survey Data and Likert Scales
# Done 253/1017
# Permutation and Combination
# Done 254/1017
# How To Master Your Casio Calculator -Total Calculator Skills
# Done 255/1017
# Introduction to Logic (Geometry Unit 2)
# Done 256/1017
# Unearthing the Trojan War: The Life of Heinrich Schliemann
# Done 257/1017
# Anatomy and Physiology
# Done 258/1017
# Breaking Down Frankenstein
# Done 259/1017
# Master the Fundamentals of Partial Derivates
# Done 260/1017
# Machiavelli on Power Politics
# Done 261/1017
# Black Belt College Writing Skills
# Done 262/1017
# Chemistry 101 - Part 3 Organic and Physical Chemistry
# Done 263/1017
# Brazil for Beginners
# Done 264/1017
# Become an Egyptologist: The Queens of Ancient Egypt
# Done 265/1017
# Academic Organization
# Done 266/1017
# Learn How to Resolve Forces in Easy Steps
# Done 267/1017
# Argument Diagramming: Beginner to Advanced
# Done 268/1017
# SAT Math Algebra - A step by step guide to a A+ in Algebra
# Done 269/1017
# Geology: Earth Science for Everyone
# Done 270/1017
# Essential Casio Calculator Skills - Succeed with Math!
# Done 271/1017
# Introduction to Matrices and Determinants - Complete
# Done 272/1017
# Write, Illustrate and Publish Your Own Children's Book
# Done 273/1017
# Statistics Concepts : Analysis of Variance (Complete Course)
# Done 274/1017
# Probability and Statistics in Psychology:College level intro
# Done 275/1017
# The Theory of Numbers - Andrew Wiles
# Done 276/1017
# Network Theory: Introduction
# Done 277/1017
# Writing an Effective Desk Research Paper
# Done 278/1017
# Explaining the Core Theories of Econometrics
# Done 279/1017
# Certified Welding Inspector "CWI" Requirements
# Done 280/1017
# General Biology I: Foundations of Biology
# Done 281/1017
# Write a Great Research Paper for Success in School!
# Done 282/1017
# Geometry - The Basics & Beyond
# Done 283/1017
# Russian Literature and Music
# Done 284/1017
# Population Aging and the Demographic Transition
# Done 285/1017
# Criminal Investigation in the New Millennium
# Done 286/1017
# Research Methods and Statistics: An Introduction
# Done 287/1017
# Learn the Bible...Right
# Done 288/1017
# World War 1 - The Christmas Truce of 1914
# Done 289/1017
# Social Psychology -- A Video Textbook
# Done 290/1017
# College Algebra - First Midterm
# Done 291/1017
# History of the Middle East - 600 A.D. to Today
# Done 292/1017
# An Introduction to Chemical Kinetics
# Done 293/1017
# Complex Systems Theory: An Introduction
# Done 294/1017
# Elixir: A History of Water and Humans
# Done 295/1017
# Workshop in Probability and Statistics from Start to Finish
# Done 296/1017
# Write a Research Proposal to Join Any University & Get Funds
# Done 297/1017
# Math Fractions - add, subtract, multiply, divide fractions
# Done 298/1017
# Transform your Research Paper Writing: Starting to Write
# Done 299/1017
# Differential Equations In Depth
# Done 300/1017
# Learn to Read for Beginner Readers
# Done 301/1017
# How to Get Published as a Graduate Student
# Done 302/1017
# The Great War
# Done 303/1017
# Boost Your Academic/Work Performance: Writing Effectively
# Done 304/1017
# Introduction to Sequences and Series
# Done 305/1017
# Essay Essentials: Improve Your Academic Writing
# Done 306/1017
# Transient State Mass Balance
# Done 307/1017
# Basic Concepts of Probability Step by Step - Complete Course
# Done 308/1017
# Whole Bible Survey: Part 3 (New Testament)
# Done 309/1017
# Victory or Death: General Washington at Trenton & Princeton
# Done 310/1017
# Mathematica 9 for Beginners
# Done 311/1017
# Physics - 12 Kinematics Questions and How to Solve Them
# Done 312/1017
# The properties of human language
# Done 313/1017
# Certified Public Accountant Tax Preparation Tutorial
# Done 314/1017
# Midwifery Basics
# Done 315/1017
# Algebra 2 & Trigonometry: A Complete High School Curriculum
# Done 316/1017
# BLUE: a symposium exploring aspects of life in ancient Egypt
# Done 317/1017
# GCSE Physics (AQA) Kinetic Energy
# Done 318/1017
# The Collection of 3D Digital Content for CHEMISTRY PART-1
# Done 319/1017
# Patterns of Inheritance: A Brief Overview
# Done 320/1017
# A Beginner's Guide to Numerical Methods in MATLAB
# Done 321/1017
# NCERT Solutions for Class 9th Maths Term 2 (SA2)
# Done 322/1017
# Text mining and content analysis
# Done 323/1017
# Introductory Biology
# Done 324/1017
# Algebra I: Straight To The Point
# Done 325/1017
# Blueprint Reading for Welders Basic Lines, Views and Symbols
# Done 326/1017
# Understanding The Screwtape Letters
# Done 327/1017
# Learning of Physics with basic concepts - Complete course
# Done 328/1017
# SmartPhysics
# Done 329/1017
# Introduction to BioDynamic Beekeeping
# Done 330/1017
# Fundamentals of Statics for Engineering Undergrads
# Done 331/1017
# Study Less, Achieve More - Untold Secrets from Inner Circle
# Done 332/1017
# Fundamentals of Space Engineering
# Done 333/1017
# Basic Concepts of Calculus Step By Step - With Easy Examples
# Done 334/1017
# Animal Physiology 1. Respiration and gas exchange
# Done 335/1017
# Understanding and Appreciating Sonnets
# Done 336/1017
# Shopper Psychology - Becoming A Smart Shopper
# Done 337/1017
# Writing Non-Fiction: The Essential Guide
# Done 338/1017
# Physics 1 (Algebra Based)
# Done 339/1017
# Greek poetry: "Ithaca" by Constantine Cavafy
# Done 340/1017
# Chemistry 101 - Part 2 Chemistry of the Elements
# Done 341/1017
# Church History: The First Five Hundred Years
# Done 342/1017
# The Early Protestant Reformation
# Done 343/1017
# Chemistry : Metals
# Done 344/1017
# GCSE chemistry AQA C1
# Done 345/1017
# Variable Frequency Drives 6.5 PDH’s Engineering Course
# Done 346/1017
# Introduction to Algebra for Secondary Schools
# Done 347/1017
# Fundamentals of Cosmometry
# Done 348/1017
# The English Reformation
# Done 349/1017
# Not Just an Introduction to Solar Power
# Done 350/1017
# The Collection of 3D Digital Content for PHYSICS PART - 1
# Done 351/1017
# Division made simple - Fastest vedic methods
# Done 352/1017
# Analyzing Sir Gawain and the Green Knight
# Done 353/1017
# GCSE Physics AQA P1
# Done 354/1017
# Fundamentals of Submarine Engineering
# Done 355/1017
# Constitutional Law in 90 Minutes: A Fast Track Summary
# Done 356/1017
# How to do Binary and Weighted habitat suitability analysis
# Done 357/1017
# Julius Caesar Part One: Early Life and Career
# Done 358/1017
# Future Masculinity
# Done 359/1017
# The Tragedy of Macbeth
# Done 360/1017
# Learn Hypothesis Testing Step by Step ( A Complete Course )
# Done 361/1017
# The American Revolution
# Done 362/1017
# Physics - Kinematics for High School and AP Physics 1
# Done 363/1017
# Quickfire Method 2 find Square Roots & Cube Roots of Numbers
# Done 364/1017
# Statistics Concepts - Sampling or Survey Sampling
# Done 365/1017
# The Weather Around You, Understanding How the Weather Works
# Done 366/1017
# Introduction to Great Books
# Done 367/1017
# Mass Balance Overview
# Done 368/1017
# The Basics of Logic: How to Reason Well
# Done 369/1017
# The Story Behind Charles Darwin and Natural Selection
# Done 370/1017
# Nonlinear Systems & Chaos: An Introduction
# Done 371/1017
# Struggling with Physics? Learn how to improve your grades
# Done 372/1017
# Apologetics:  The Top Ten Questions of the Christian Faith
# Done 373/1017
# The Independent Samples T-Test: A Crash Course
# Done 374/1017
# International Relations 1815-1914
# Done 375/1017
# Whole Bible Survey: Part 1 (Old Testament)
# Done 376/1017
# Time Management
# Done 377/1017
# How to do percentages in less than 2 hours
# Done 378/1017
# Get Your Research Published in The Best Matching Journals
# Done 379/1017
# Is American Democracy Broken? Perspectives and Debates
# Done 380/1017
# Learn How To Read Literature: Elements of Fiction
# Done 381/1017
# Which is Scientific, the Bible or Atheism?
# Done 382/1017
# Reading & Study Habits: Home School, High School, or College
# Done 383/1017
# Systems Thinking Made Simple
# Done 384/1017
# March MATHness
# Done 385/1017
# Ultimate guide to math word problems Intermediate Part One
# Done 386/1017
# Maths Made Easy and Quick
# Done 387/1017
# ACT, SAT And CXC CSEC Math: Algebra Mastery
# Done 388/1017
# Understanding Macroeconomics for University and Business
# Done 389/1017
# Physics: Master 2D Torque in Record Time
# Done 390/1017
# Calculus III (Multivariable Calculus)
# Done 391/1017
# Core Spatial Data Analysis: Introductory GIS with R and QGIS
# Done 392/1017
# ATOLL PRO: Introduction to Aquaculture
# Done 393/1017
# Nuclear South Asia
# Done 394/1017
# Circuit Analysis and Design : Part 1
# Done 395/1017
# The invention of the Euro - Robert Mundell
# Done 396/1017
# The Basics of Space for Absolute Beginners & Students
# Done 397/1017
# Biophysical Field Methods
# Done 398/1017
# A basic Arithmetic Course
# Done 399/1017
# Statistics Concepts - Measures of Dispersion Step by Step
# Done 400/1017
# World War I: The Western Front
# Done 401/1017
# Topics in Algebra: Strategies for Solving Equations
# Done 402/1017
# Approaches to Islam: Theological and Practical
# Done 403/1017
# Quick Math
# Done 404/1017
# The Complete Starter Guide to Climate Change
# Done 405/1017
# A beginner's guide to Word Problems
# Done 406/1017
# Analytic Trigonometry - Your Complete Guide
# Done 407/1017
# Wave Optics And Interference of light
# Done 408/1017
# Property Law: A Comprehensive Summary
# Done 409/1017
# The Life of Moses
# Done 410/1017
# College Survival Study Skills
# Done 411/1017
# Statistics Concepts for beginners From Start to Finish
# Done 412/1017
# The RMS Lusitania
# Done 413/1017
# The Battle of Gettysburg
# Done 414/1017
# Introduction to Medical Imaging
# Done 415/1017
# Theme Park Design
# Done 416/1017
# Depression, War and Recovery; Britain 1931-1951
# Done 417/1017
# Learn the Law: A 5 Hour Fast Track Masterclass Summary
# Done 418/1017
# Middle East 101. Become an expert overnight.
# Done 419/1017
# The Game Theory - John Nash
# Done 420/1017
# The Holy Spirit Seminar
# Done 421/1017
# Basic Concepts of Biology From Start to Finish - Complete
# Done 422/1017
# 2014 Great Decisions: Foreign Policy Association
# Done 423/1017
# Learn Chi-Square from beginning to advance level
# Done 424/1017
# The Battle of the Crater
# Done 425/1017
# The Neuroscience of Habits
# Done 426/1017
# Public Speaking for High School Students: Speak Well Now
# Done 427/1017
# Maths question Bank for grade 1-8
# Done 428/1017
# Probability made easy: Expected value and variance
# Done 429/1017
# Mapping Online - Easy to create professional map mash-ups
# Done 430/1017
# Writing a Thesis, Paper or Research Project: Getting Started
# Done 431/1017
# Understanding Romantic Poetry
# Done 432/1017
# First Anatomy Arm Muscles
# Done 433/1017
# Fundamental Topics in Algebra Real Simple
# Done 434/1017
# Physical Geology
# Done 435/1017
# Law: A Comprehensive Summary for LLB Students
# Done 436/1017
# Discrete Mathematics: Open Doors to Great Careers
# Done 437/1017
# Western Military History - Part 1:  The Classical World
# Done 438/1017
# Mechanics Statics 1.1
# Done 439/1017
# Physics 12: Classical Mechanics
# Done 440/1017
# Pontius Pilate
# Done 441/1017
# Introduction to Qualitative Research Methods
# Done 442/1017
# Foundations of Biblical Interpretation
# Done 443/1017
# The Collection of 3D Digital Content for BIOLOGY PART -1
# Done 444/1017
# Maths grade 8 (1 of 5) Numbers, Operations & Relationships
# Done 445/1017
# HSE/GED/TASC/HiSET Prep (Unit 1 - Arithmetic)
# Done 446/1017
# A Companion to The Great Divorce
# Done 447/1017
# Introduction to Sociology
# Done 448/1017
# Mathematics of Finance
# Done 449/1017
# Bible Study: Ephesians - 7 Lessons We Can Learn For Today!
# Done 450/1017
# Primer Design For Polymerase Chain Reaction-Tips & Tricks
# Done 451/1017
# Finally Conquer Fractions
# Done 452/1017
# Backyard Astronomy II
# Done 453/1017
# The Human Genome - James Watson
# Done 454/1017
# Commercial Law in 150 Minutes: A Fast Track Summary
# Done 455/1017
# College Algebra Explained
# Done 456/1017
# Animal Physiology 2. Blood, circulation and gas exchange
# Done 457/1017
# U.S. History 201
# Done 458/1017
# Get An Amazing Memory: Memorize Deck of Cards
# Done 459/1017
# Static Structures - Reactions
# Done 460/1017
# APA style referencing for complete beginners
# Done 461/1017
# Writing Your Dissertation
# Done 462/1017
# The Collection of 3D Digital Content for BIOLOGY PART - 2
# Done 463/1017
# Kilts and Kerns: The Scots-Irish Connection Part 1
# Done 464/1017
# The Collection of 3D Digital Content for BIOLOGY PART - 3
# Done 465/1017
# Treating Victims of Bullying
# Done 466/1017
# How to Solve Linear Equations in 5 Simple Steps
# Done 467/1017
# Mathematics Grade 8 (4 of 5) - Measurement
# Done 468/1017
# Academic Writing Essentials: A College Writing Crash Course
# Done 469/1017
# How The Economy Really Works
# Done 470/1017
# Physics Essentials 1
# Done 471/1017
# The Stock Market - Robert Merton
# Done 472/1017
# Capitalism in Crisis: The global economic crisis explained
# Done 473/1017
# Learn Redox Reactions In Easy Steps (Chemistry)
# Done 474/1017
# Physics: Intro to Electricity & Magnetism
# Done 475/1017
# Become a Mechanics Pro!
# Done 476/1017
# Visualization and Imputation of Missing Data
# Done 477/1017
# Easy Binary, Hexadecimal, and Octal Math Conversion
# Done 478/1017
# Why are you alive? - Introduction
# Done 479/1017
# Learn to Differentiate and Integrate in 45 minutes
# Done 480/1017
# The Collection of 3D Digital Content for CHEMISTRY PART-3
# Done 481/1017
# Learn to Sketch Curves using Calculus
# Done 482/1017
# Test of Hypotheses, Simplified Engineering Approach
# Done 483/1017
# The Collection of 3D Digital Content for CHEMISTRY PART-2
# Done 484/1017
# Matrix Algebra
# Done 485/1017
# Warp Speed Math (Addition) - Learning Math the Faster Way
# Done 486/1017
# Medicare
# Done 487/1017
# OpenSesame: The Experiment Building Software
# Done 488/1017
# The Collection of 3D Digital Content for PHYSICS PART - 3
# Done 489/1017
# The Psychology of Learning -- A Video Textbook
# Done 490/1017
# Learn Confidence Interval step by step ( A Complete Course )
# Done 491/1017
# Trigonometry: Your Complete Guide
# Done 492/1017
# Current Electricity
# Done 493/1017
# The Castles of Mad King Ludwig
# Done 494/1017
# Math - How to Factor
# Done 495/1017
# 2D Vector Basics For Unity
# Done 496/1017
# The Collection of 3D Digital Content for PHYSICS PART - 4
# Done 497/1017
# Vedic Mathematics - The Complete Guide
# Done 498/1017
# Engineering Mechanics for 1st Year Engineering Students
# Done 499/1017
# Beginner Calculus
# Done 500/1017
# The Collection of 3D Digital Content for PHYSICS PART -5
# Done 501/1017
# Organic Chemistry: A Review with Flashcards, college or MCAT
# Done 502/1017
# Learn Methods of Hidden Manipulation and Human Management
# Done 503/1017
# Jane Austen: A Quick & Unique Guide to Successful Reading
# Done 504/1017
# Forensic Anthropology - Skeletal analysis
# Done 505/1017
# Rail Vehicle Engineering 101
# Done 506/1017
# Learn Algebra, from Beginner to Advanced equations
# Done 507/1017
# Presocratics and the Birth of Philosophy - Emanuele Severino
# Done 508/1017
# Orson Welles and the 1938 The War of the Worlds Broadcast
# Done 509/1017
# New Trends in Outer Space Development
# Done 510/1017
# Hypothesis testing in college level statistics - Part 1-
# Done 511/1017
# Introduction to Stata - Hands on!
# Done 512/1017
# Topics in Algebra: Graphing
# Done 513/1017
# The Reconstruction Era 1862-1877
# Done 514/1017
# Mastering Organic Chemistry From the Start
# Done 515/1017
# Ancient Egypt: Exploring Its Splendor
# Done 516/1017
# GCSE Physcis (AQA) Forces and their Effects
# Done 517/1017
# Introduction to Social Insects
# Done 518/1017
# Introduction to Screenwriting: The Basics of the Craft
# Done 519/1017
# The UC Application Strategy Guide
# Done 520/1017
# Learn how to use statistics step by step.
# Done 521/1017
# Postulates, Properties, and Proofs (Geometry Unit 3)
# Done 522/1017
# Enrichment analysis: interpret gene lists like a pro
# Done 523/1017
# Standout Statements - Get in to Your Top Graduate Program
# Done 524/1017
# Halloween Law School
# Done 525/1017
# Macro Watch: Fourth Quarter 2013
# Done 526/1017
# How To Become A Naturopathic Doctor
# Done 527/1017
# Animal Physiology 3. Digestion and metabolism
# Done 528/1017
# Human Development
# Done 529/1017
# Scientific Word Technical Typesetting (WYSIWYG LaTeX)
# Done 530/1017
# Ms Cooper's IGCSE Biology: mastering the first 7 topics
# Done 531/1017
# How We Got the Bible
# Done 532/1017
# ANOVA using MS Excel
# Done 533/1017
# LEGO Robotic C Programming
# Done 534/1017
# Learn Economics From Scratch -  An A Level Support Course
# Done 535/1017
# American History from 1865 - Reconstruction
# Done 536/1017
# Basic Geometry
# Done 537/1017
# The Mind-Music Connection
# Done 538/1017
# Economics, Ethics and Justice - Amartya Sen
# Done 539/1017
# Max Planck – Sheldon Lee Glashow
# Done 540/1017
# Fun, Simple and Useful Math for Kids! (Part 6/6)
# Done 541/1017
# Evolutionary biology for the enquiring mind
# Done 542/1017
# Advance Vedic Math: Increase your Calculation Speed upto10x
# Done 543/1017
# The Mujerista Theology of Ada María Isasi-Díaz: A Study
# Done 544/1017
# Maxima and Minima  concepts : Applications of Derivatives
# Done 545/1017
# Power Pre-Algebra
# Done 546/1017
# Breakthrough Research Discoveries & Laws of Human Nature
# Done 547/1017
# High School Algebra For Beginners
# Done 548/1017
# Ultimate guide to IGCSE Math (0580)
# Done 549/1017
# Revise Further OCR Biology Quickly
# Done 550/1017
# Maths GCSE 2017 - Revise & Learn: Number
# Done 551/1017
# Introduction to the Chemical Reactor Design
# Done 552/1017
# Transformed by Beauty
# Done 553/1017
# Mastering and Tuning Decision Trees
# Done 554/1017
# Animal Physiology 4: Temperature, heat and water balance
# Done 555/1017
# Lavoisier and Mendeleev - Harold Kroto
# Done 556/1017
# Learn Organic Chemistry 2 and pass your exams!
# Done 557/1017
# DNA the Secret of Life - James Watson
# Done 558/1017
# Judaism and Christianity: Same But Different
# Done 559/1017
# Roof Runoff Structure Design (NRCS Standard 558)
# Done 560/1017
# Singapore Math: Place Value Addition
# Done 561/1017
# The Law of Torts Made Easy (New August 2016 Course)
# Done 562/1017
# Genetics I for High School: Getting to know the DNA Molecule
# Done 563/1017
# Learn Probability concepts and counting techniques
# Done 564/1017
# Introduction to Differentiation (Differential Calculus)
# Done 565/1017
# JMed Anatomy
# Done 566/1017
# Learn Algebra in 10 Minutes a Day
# Done 567/1017
# Mathematics Grade 8 (3 of 5) - Space & Shape
# Done 568/1017
# Breaking Down Pride and Prejudice
# Done 569/1017
# GCSE Physics (Edexcel) Momentum, Energy, Work and Power
# Done 570/1017
# Introduction to the Middle Ages
# Done 571/1017
# Fundamentals of Trigonometry
# Done 572/1017
# Human Physiology
# Done 573/1017
# NCERT Solutions for Class 10th Maths Term 2 (SA2)
# Done 574/1017
# Grade 6/7 Math (British Columbia, Canada Curriculum)
# Done 575/1017
# Step by Step Calculus 1 : Learn from scratch
# Done 576/1017
# Year 12 VCE Biology
# Done 577/1017
# Study Tips & Hacks for University: SUPERCHARGE Your Grades!
# Done 578/1017
# NCERT Solutions for Class 10 Maths Chapter 8 Trigonometry
# Done 579/1017
# A Glimpse of Chinese Culture
# Done 580/1017
# Speed Math In Your Head
# Done 581/1017
# MS Excel: Statistics and Data Analysis
# Done 582/1017
# U.S. History 202
# Done 583/1017
# The Human Eye and the Colorful World
# Done 584/1017
# Confidence intervals and sample sizes estimations
# Done 585/1017
# Complex Adaptive Systems
# Done 586/1017
# Calculus : Limits and Continuity
# Done 587/1017
# Creating Better Readers through Storytime
# Done 588/1017
# Learn ACT Math
# Done 589/1017
# Conquering Math: Algebra II - Quadratic Functions
# Done 590/1017
# 5. Ordinary Simple Annuities : Advanced Problems
# Done 591/1017
# Sampling Distribution
# Done 592/1017
# Public Speaking for Kids and Teens
# Done 593/1017
# Mathematics Core Concepts
# Done 594/1017
# Math: How To Go From Struggle To Mastery In Fractions
# Done 595/1017
# GCSE Physics (OCR21) P5 Electric Circuits
# Done 596/1017
# Community Service Engineering
# Done 597/1017
# Introduction to Integration (Integral Calculus)
# Done 598/1017
# History and Security in the Middle East
# Done 599/1017
# What Kids Learn in Math Class that You Never Learned: Basics
# Done 600/1017
# Introduction to Human Anatomy and Physiology: An Orientation
# Done 601/1017
# Maximum Power Point Tracking (MPPT) Design and Control
# Done 602/1017
# Understanding Feasts, Festivals and Holy Days in the Bible
# Done 603/1017
# Electro Chemical Kinetics
# Done 604/1017
# 7. General Annuities
# Done 605/1017
# Modern Physics
# Done 606/1017
# Enhancing Research Visibility and Improving Citations
# Done 607/1017
# Probability 1 - 40 Solved Problems - The Math of Counting
# Done 608/1017
# An Introduction to Basic Biology
# Done 609/1017
# Essay Writing Basics
# Done 610/1017
# Instant Anatomy: A course in Human Anatomy
# Done 611/1017
# JEE/AIPMT Exam Prep: Essentials of Physical Chemistry
# Done 612/1017
# Heat
# Done 613/1017
# Learn how to become a math whizz
# Done 614/1017
# Colourful Maths! How to Draw Any Linear Graph
# Done 615/1017
# Introduction to Exponent (Index), Surd and Logarithm
# Done 616/1017
# Physics - Dynamics for High School and AP Physics 1
# Done 617/1017
# Complexity Economics An Introduction
# Done 618/1017
# Plant Physiology
# Done 619/1017
# A-Level Statistics
# Done 620/1017
# GCSE Chemistry: OCR C1
# Done 621/1017
# Strategic Economic Decision-Making
# Done 622/1017
# Electromagnetism
# Done 623/1017
# Complexity science: an introducton
# Done 624/1017
# Getting Out There - Anthropology On Terrain
# Done 625/1017
# Anatomy of A Pandemic: Ebola Disease in the 21st Century
# Done 626/1017
# Clinical Application of Functional Neurology
# Done 627/1017
# 1st Grade Common Core Math - Part 1
# Done 628/1017
# Russian Literature for Dummies
# Done 629/1017
# Vasopressors & Inotropes
# Done 630/1017
# IBM SPSS: Statistical Data Analysis Made Easy
# Done 631/1017
# Calculus: Integration by using Partial Fraction method
# Done 632/1017
# Basic Introduction to Economics
# Done 633/1017
# Genealogy: Learn to Climb the Branches of Your Family Tree
# Done 634/1017
# Writing about Race in Academic Study
# Done 635/1017
# The Psychology of Personality -- A Video Textbook
# Done 636/1017
# Social Complexity An Introduction
# Done 637/1017
# Physical Metallurgy 2
# Done 638/1017
# Hypothesis Testing using MS Excel
# Done 639/1017
# Conduct a Two-Way ANOVA Using SPSS
# Done 640/1017
# Dynamics and Gravitation
# Done 641/1017
# Real Numbers
# Done 642/1017
# Ecosystem ecology
# Done 643/1017
# The Living World
# Done 644/1017
# LGBTQs in Asia: An Introduction
# Done 645/1017
# An Advocacy Algorithm—For Today's Global Citizens
# Done 646/1017
# Angles (Geometry Unit 4)
# Done 647/1017
# Changing Lands and Faiths
# Done 648/1017
# Introduction to Psychology
# Done 649/1017
# Maxwell: Electricity, magnetism and light - S. L. Glashow
# Done 650/1017
# Lectures on William Blake, the Poet and the Artist
# Done 651/1017
# Understanding Beowulf
# Done 652/1017
# Mathematics Grade 8 (2 of 5) - Patterns, Functions & Algebra
# Done 653/1017
# Of Markets & Men:A Visual Introduction to Austrian Economics
# Done 654/1017
# Mathematics Grade 8 (5 of 5) - Data Handling
# Done 655/1017
# The Collection of 3D Digital Content for PHYSICS PART - 2
# Done 656/1017
# Simple Steps to Solve Math Word Problems
# Done 657/1017
# Word Problems Made Easy!
# Done 658/1017
# The Collection of 3D Digital Content for BIOLOGY PART - 4
# Done 659/1017
# Advanced Algebra: Strategies for Success
# Done 660/1017
# Control Valves 101
# Done 661/1017
# Cell: Structure and functions
# Done 662/1017
# Mass Balance Basics
# Done 663/1017
# Topics in Algebra: Polynomials and Factoring
# Done 664/1017
# Beijing's inner city gate
# Done 665/1017
# Physics - Energy and Momentum - High School and AP Physics
# Done 666/1017
# Periodic Table Part - 1
# Done 667/1017
# Excellent Argumentative Essay Writing
# Done 668/1017
# Some basic concepts of chemistry
# Done 669/1017
# Wave Nature
# Done 670/1017
# Waves
# Done 671/1017
# The Beginning of AI
# Done 672/1017
# Systems Ecology An Introduction
# Done 673/1017
# Physics - Modern Physics - High School and AP Physics
# Done 674/1017
# Differential Equations
# Done 675/1017
# Learn the Perfect Way to Answer GCSE Maths Exam Questions
# Done 676/1017
# Programmable Logic Controller RSLogix 500 (2 PDH's for PE's)
# Done 677/1017
# College Algebra - Second Midterm
# Done 678/1017
# Physics - Waves, Sound, & Optics - High School & AP Physics
# Done 679/1017
# Probability for Beginners : Building a Foundation (Part 2)
# Done 680/1017
# Practical Mathematics 1: The Numbers
# Done 681/1017
# Tackling and mastering inheritance, selection and variation
# Done 682/1017
# Macro Analysis Bootcamp
# Done 683/1017
# Recurrence Relation Made Easy
# Done 684/1017
# Atomic Physics
# Done 685/1017
# Divine New York City
# Done 686/1017
# Analysis of Criminal Behavior
# Done 687/1017
# Sport psychology The Balance of sportsman's life
# Done 688/1017
# Periodic Table Part - 2
# Done 689/1017
# First Year University Calculus: Integrals
# Done 690/1017
# A Gentle Introduction to Quantum Mechanics
# Done 691/1017
# An Introduction to Heat Transfer
# Done 692/1017
# Colourful Maths! Circular Functions
# Done 693/1017
# Light
# Done 694/1017
# Kinematics
# Done 695/1017
# Taking Live Field Notes: Advanced Qualitative Techniques
# Done 696/1017
# Foundations of the Gael
# Done 697/1017
# Algebra Foundations for Calculus
# Done 698/1017
# Complex Numbers (Part-1)
# Done 699/1017
# Whole Bible Survey: Part 2 (Old Testament cont)
# Done 700/1017
# Algebra I : Key Concepts for High School Students
# Done 701/1017
# Basics of Medical Microbiology
# Done 702/1017
# Research Project Management: Getting Started
# Done 703/1017
# Shakespeare: How to access the power of words!
# Done 704/1017
# Quadratic Equations; Your Complete Guide
# Done 705/1017
# The Day the Revolution Began
# Done 706/1017
# The American Civil War
# Done 707/1017
# Graph Theory
# Done 708/1017
# Nutrition and some common diseases
# Done 709/1017
# Introduction of physics
# Done 710/1017
# Single Phase Mass Balance
# Done 711/1017
# Professional Social Work in the United States
# Done 712/1017
# Learn Alkene Synthesis and Pass Organic Chemistry Tests!
# Done 713/1017
# Biology in Human Welfare
# Done 714/1017
# Mathematics 101: Building a Solid Foundation
# Done 715/1017
# Common Core Pre-Algebra
# Done 716/1017
# Basics of Reservoir Engineering
# Done 717/1017
# Mastering Speed Mathematics  and Mental Maths Tricks
# Done 718/1017
# The Study Smarter Series - Six Study Courses Rolled Into One
# Done 719/1017
# Parallel Lines and Transversals (Geometry Unit 5)
# Done 720/1017
# Hydrocarbons
# Done 721/1017
# Conduct a One-Way MANOVA Using SPSS
# Done 722/1017
# Energy in different forms
# Done 723/1017
# First Year University Calculus: vectors, planes and surfaces
# Done 724/1017
# How to Trade the Stock Market - For School Students
# Done 725/1017
# Understand Quadratics and Parabolas
# Done 726/1017
# Beginner Writer Course: Introduction to Literary Elements
# Done 727/1017
# Become a Master in AP Marcoeconomics
# Done 728/1017
# Learn Successful Study Skills:
# Done 729/1017
# States of matter
# Done 730/1017
# Biotechnology
# Done 731/1017
# Physics - Regents Physics Content and Exam Review
# Done 732/1017
# How to Get a Thesis: for Students and Supervisors
# Done 733/1017
# GCSE Physics - P4 explaining motion (OCR 21st C Science)
# Done 734/1017
# Around the World Math and Literacy Fun for Kids
# Done 735/1017
# First Year University Calculus: Lagrange Multipliers
# Done 736/1017
# 11+ Exam Preparation / UK Grammar and Private Schools
# Done 737/1017
# ben franklin, american initiate
# Done 738/1017
# The Magic in Science
# Done 739/1017
# Common Core Math - Grade 4 - Module 1
# Done 740/1017
# Moving Pictures
# Done 741/1017
# Scope Of science
# Done 742/1017
# Probability and Counting Techniques
# Done 743/1017
# Food Energy Water: Foundation systems of Modern Society
# Done 744/1017
# sıfırdan matematik
# Done 745/1017
# Competencias Tecnológicas en la Comunicación
# Done 746/1017
# Análisis de series
# Done 747/1017
# Interpreta los mensajes ocultos del arte del Renacimiento
# Done 748/1017
# contrastes de hipotésis: aprueba estadística inferencial
# Done 749/1017
# Neurociência aplicada aos negócios
# Done 750/1017
# aprueba econometría ahorrando tiempo
# Done 751/1017
# Introducción a la economía
# Done 752/1017
# Adım Adım CFD | Hesaplamalı Akışkanlar Dinamiği
# Done 753/1017
# integrales multiples
# Done 754/1017
# Fuentes de información geográfica para SIGs ambientales
# Done 755/1017
# Lógica proposicional básica
# Done 756/1017
# Mastering Electric Circuit 1 - Basic Laws
# Done 757/1017
# Area Model,factorization &Order of Operation
# Done 758/1017
# Chemistry Through the Ages
# Done 759/1017
# Economic  Inequality: An International Approach - Course I
# Done 760/1017
# International Humanitarian Law in 60 Minutes
# Done 761/1017
# Colourful Maths! Powers, Logarithms and their graphs
# Done 762/1017
# Introduction to ThermoFluids
# Done 763/1017
# Create an Assignment Introduction that will Max your grades
# Done 764/1017
# Economic Inequality: An International Approach - Course II
# Done 765/1017
# The Four Essential Keys to Choosing a College
# Done 766/1017
# VCE Maths Methods - The Different Types of Graphs
# Done 767/1017
# Live Intensely, Fully Energized for Education
# Done 768/1017
# An Introduction to Symbiosis
# Done 769/1017
# accessibility Codes and Laws an overview
# Done 770/1017
# Historical Assemblies (The Tudors)
# Done 771/1017
# Wright Arts Camp: The Curriculum
# Done 772/1017
# Colourful Maths! Calculus for beginners
# Done 773/1017
# Macro Watch: First Quarter 2014
# Done 774/1017
# GCSE Physics (OCR Gateway) P4 Radiation for Life
# Done 775/1017
# Simple Linear Regression Basics using R
# Done 776/1017
# Maths GCSE 2017 - Revise & Learn: Ratio and Proportion
# Done 777/1017
# GCSE Physics (AQA) P2
# Done 778/1017
# Introduction to Advanced Mathematics
# Done 779/1017
# International Humanitarian Law in 60 Minutes
# Done 780/1017
# Quantum Numbers Crash Course for High School Chemistry
# Done 781/1017
# Chemical compounds
# Done 782/1017
# Introduction to Website Survey Sampling
# Done 783/1017
# Climate and catastrophe and war
# Done 784/1017
# GCSE Physics (Edexcel) P2 Physics for your Future
# Done 785/1017
# Colourful Maths! How to Sketch Any Graph
# Done 786/1017
# Sigmund Freud's Theories
# Done 787/1017
# Linear Equations and Inequalities; Your complete guide
# Done 788/1017
# Developmental Theories in Psychology Part I
# Done 789/1017
# Banter: Secondary systems that steer society
# Done 790/1017
# GCSE Physics (OCR Gateway) P3 Forces for Transport
# Done 791/1017
# Solving quadratic equations using various methods
# Done 792/1017
# Introducción al mundo del conocimiento complejo
# Done 793/1017
# Diseño Mecánico Fácil
# Done 794/1017
# Derivadas Parciales
# Done 795/1017
# Calculo Vectorial
# Done 796/1017
# Herramientas para la escritura académica: Artículos/Tesis
# Done 797/1017
# Teledetección y análisis de superficies con ArcGis 10.
# Done 798/1017
# SIGs para estudios de Biodiversidad y Conservación
# Done 799/1017
# Diseño de Sistemas de Drenaje Urbano
# Done 800/1017
# Técnicas de estudio: Cómo estudiar mejor y más rápido
# Done 801/1017
# Aprende a Seleccionar Bombas Centrífugas
# Done 802/1017
# Series de Fourier
# Done 803/1017
# Incendios forestales: domina el INFOCA en sólo 8 vídeos.
# Done 804/1017
# Learn Primary School Maths Strategies Yr2 (age 6&7)
# Done 805/1017
# American & Canadian Football History  where it began .
# Done 806/1017
# Level up Math the Best Math Course
# Done 807/1017
# Stress-Free College Applications
# Done 808/1017
# People Power, Civil Resistance, and Social Transformation
# Done 809/1017
# GCSE Physics (OCR21) P6 Radioactive Materials
# Done 810/1017
# Design and control of 3DOF robotic arm
# Done 811/1017
# HSE/GED/TASC/HiSET Prep (Unit 2 - Word Problems)
# Done 812/1017
# Maxima and Minima 2 : Applications of Derivatives
# Done 813/1017
# Geometry Basics (Geometry Unit 1)
# Done 814/1017
# 2nd Grade Math Common Core Content Standards
# Done 815/1017
# Introduction to Trigonometry (Algebra 2 Unit 14)
# Done 816/1017
# Fundamentos de Investigación científica
# Done 817/1017
# Wechselstrom und Zeigerdiagramme
# Done 818/1017
# Neurociencia en los negocios
# Done 819/1017
# Netzwerke berechnen mit der Ersatzspannungsquelle
# Done 820/1017
# Quellenverwaltung mit Zotero – der Schnellkurs
# Done 821/1017
# SIG aplicados al medio ambiente con arcGIS 10.
# Done 822/1017
# Cómo estructurar y redactar una tesis de investigación
# Done 823/1017
# Google Earth Pro. Llega a experto desde cero.
# Done 824/1017
# プログラミングで科学を学ぼう！ Vol. 1
# Done 825/1017
# Curso de electricidad basica
# Done 826/1017
# Transformada de Laplace
# Done 827/1017
# Mandalas e seu uso terapêutico
# Done 828/1017
# Ejercicios resueltos de geometría plana
# Done 829/1017
# Kısa Yoldan Matematik
# Done 830/1017
# Matemáticas Pre-U: Trigonometría y Geometría Analítica
# Done 831/1017
# สรุปเข้ม ม.1 ความสัมพันธ์ระหว่างรูปเรขาคณิต 2 มิติ และ3 มิติ
# Done 832/1017
# Direito Bancário - Relações de consumo tarifas e produtos
# Done 833/1017
# Matemáticas Pre-U: Cálculo Diferencial e Integral
# Done 834/1017
# YGS denemeleri
# Done 835/1017
# Fundementals of PhotoVoltaics اساسيات الخلايا الشمسية
# Done 836/1017
# Akışkanlar Mekaniği Soru Çözümleri
# Done 837/1017
# Variable compleja: Números complejos y límites
# Done 838/1017
# Biologia - Intensivo para Enem e Vestibulares
# Done 839/1017
# Matrices en matemáticas para bachillerato
# Done 840/1017
# Divine Principle
# Done 841/1017
# Culvert Design using HY-8
# Done 842/1017
# HSE/GED/TASC/HiSET Prep (Unit 3 - Negative Numbers)
# Done 843/1017
# The Emergent Human Series- SDi Primer
# Done 844/1017
# Insights into cybercrime and electronic evidence
# Done 845/1017
# A Brief History of Tamil Country
# Done 846/1017
# Stream Crossing Design (NY NRCS Standard 578)
# Done 847/1017
# The Physics of Sports
# Done 848/1017
# Mountain Plants of South-West China
# Done 849/1017
# Flash Speed Squaring of Numbers
# Done 850/1017
# Holigent Solution: Building a Better Bridge to Our Future
# Done 851/1017
# Grassland Curing
# Done 852/1017
# Divine Principle Part 2
# Done 853/1017
# Unit 3 Feeling Homesick 10th G.ES High school.
# Done 854/1017
# TCC - Trabalho de Conclusão de Curso
# Done 855/1017
# Introducción al Marketing
# Done 856/1017
# Introducción a los Derechos Humanos
# Done 857/1017
# Igualdad de Género y Diversidad Sexual
# Done 858/1017
# Introducción a la Estadística
# Done 859/1017
# Introducción a la Economía
# Done 860/1017
# Transparencia y Anti-Corrupción
# Done 861/1017
# Construye un drone quadrotor desde cero
# Done 862/1017
# Escribir un ensayo
# Done 863/1017
# Matrices y sistemas de ecuaciones (Álgebra Lineal)
# Done 864/1017
# Türev-2
# Done 865/1017
# İntegral 2
# Done 866/1017
# İntegral 3
# Done 867/1017
# PROBLEMLER-6 (Hareket (hız) problemleri)
# Done 868/1017
# Contabilidad pública: Presupuesto de Gastos e Ingresos
# Done 869/1017
# Como ser Excelente Alumno
# Done 870/1017
# Fracciones fáciles para todos
# Done 871/1017
# Identificación de peligros y gestión de riesgos e impactos
# Done 872/1017
# Diseño mecánico en Creo Parametric (Pro/Engineer).
# Done 873/1017
# Prozentrechnen - verstehen und üben - Nachhilfe
# Done 874/1017
# สรุปเข้ม ม.1 เลขยกกำลัง
# Done 875/1017
# El Acceso a la Información y Transparencia en 40 Lecciones.
# Done 876/1017
# Dominando Cálculo Integral
# Done 877/1017
# SPSS ile Biyoistatistik Kursu"3 (SPSS'te Graph menüsü)
# Done 878/1017
# Matemáticas pre-universitarias: multiplica tu aprendizaje
# Done 879/1017
# Položi Matematiku 2 na idućem roku! Lakše je nego što misliš
# Done 880/1017
# SPSS'le Biyoistatistik Kursu"5 P.metrik&Non.p.metrik testler
# Done 881/1017
# Proportionalität - verstehen und üben - Nachhilfe
# Done 882/1017
# Wissenschaftliches Arbeiten – der Grundkurs für alle
# Done 883/1017
# Cómo hacer la tesis paso a paso y cómo sustentarla
# Done 884/1017
# Productos Notables
# Done 885/1017
# Atrévete a escribir -Taller de literatura para principiantes
# Done 886/1017
# Lectura y escritura: ¿Cómo empezar a leer?
# Done 887/1017
# Uso básico del iPad
# Done 888/1017
# Productos Notables Incluye Problemas de Examen Resueltos
# Done 889/1017
# Desigualdades e Inecuaciones
# Done 890/1017
# สรุปเข้ม ม.1 ห.ร.ม. และ ค.ร.น.
# Done 891/1017
# CÍRCULO TRIGONOMÉTRICO: Cuadrantes, Seno, Coseno y Tangente
# Done 892/1017
# Introduccion a la Cooperacion Internacional
# Done 893/1017
# สรุปเข้ม ม.3 พื้นที่ผิว ปริมาตร และการประยุกต์
# Done 894/1017
# Factorizar Expresiones Algebraicas y Polinomios por Ruffini
# Done 895/1017
# ม.ปลาย การให้เหตุผล
# Done 896/1017
# สรุปเข้ม ม.1 พื้นฐานทางเรขาคณิต
# Done 897/1017
# Principios para una Educación Responsable en Gestión - PRME
# Done 898/1017
# สรุปเข้ม ม.1 ระบบจำนวนเต็ม
# Done 899/1017
# สรุปเข้ม ม.2 อัตราส่วนและร้อยละ
# Done 900/1017
# Diseño Profesional de Cursos Online AIC
# Done 901/1017
# Geografia
# Done 902/1017
# História
# Done 903/1017
# 現役プラネタリウム解説員が教える、星座に隠されたストーリーと季節ごとの星座の見つけ方
# Done 904/1017
# 姚立明老師談民主 (繁體中文)
# Done 905/1017
# Curso de Estadística
# Done 906/1017
# Direito de Família - aspectos práticos.
# Done 907/1017
# Diseño de instalaciones solares térmicas
# Done 908/1017
# 78 Ejercicios resueltos de Límites
# Done 909/1017
# Dê Cartas Em Gestão Financeira!
# Done 910/1017
# Haus-/Abschlussarbeit sofort optimieren!
# Done 911/1017
# SPSS ile Biyoistatistik Kursu"2 (SPSS te Temel kavramlar)
# Done 912/1017
# SPSS ile Biyoistatistik Kursu"4  (Normallik ve Outliers )
# Done 913/1017
# Scratchで学ぶ科学的思考プログラミング　前編
# Done 914/1017
# Scratchで学ぶ科学的思考プログラミング　中編
# Done 915/1017
# Scratchで学ぶ科学的思考プログラミング　後編
# Done 916/1017
# Língua Portuguesa
# Done 917/1017
# 【学生編】東大の入試問題で「数学的センス」が身につく
# Done 918/1017
# Resuelve ecuaciones lineales con 2 variables
# Done 919/1017
# Matemática
# Done 920/1017
# Text mining e analisi del contenuto
# Done 921/1017
# プログラミングで科学を学ぼう！ Vol. 9
# Done 922/1017
# Química
# Done 923/1017
# Literatura
# Done 924/1017
# 動画で学ぶ、子供の能力（成績）を向上させるための講座
# Done 925/1017
# プログラミングで科学を学ぼう！ Vol. 10
# Done 926/1017
# Matemáticas Mágicas - calcula mentalmente, mejora tu trabajo
# Done 927/1017
# Factorización usando la Regla de Ruffini-Curso Introductorio
# Done 928/1017
# Solución gráfica de ecuaciones linales
# Done 929/1017
# 化学が好きになる手引き
# Done 930/1017
# Filosofia
# Done 931/1017
# Sociologia
# Done 932/1017
# Biologia
# Done 933/1017
# İntegral 1
# Done 934/1017
# Matematik-1:"YGS-LYS Konu Anlatımları, Örnek Soru Çözümleri"
# Done 935/1017
# Dê Cartas em Gestão de Empresas!
# Done 936/1017
# As Seis Lições - Leitura comentada de Ludwig von Mises
# Done 937/1017
# Wissenschaftliche Arbeiten schreiben in nur 8 Schritten
# Done 938/1017
# Cómo Diseñar el Suministro de Agua Potable de Edificaciones
# Done 939/1017
# Crea tus propias rutas y gana dinero enseñando tu ciudad
# Done 940/1017
# Orta Asya Türk Tarihi
# Done 941/1017
# ArcGIS 10.1 Desde Cero. Sistemas de Información Geográfica
# Done 942/1017
# Я хочу учиться за рубежом!
# Done 943/1017
# Cómo ser excelente alumno Curso Introductorio
# Done 944/1017
# Merkur – der geheimnisvolle Planet
# Done 945/1017
# Curso de Iniciación a la Arqueología y SIG
# Done 946/1017
# Položi Matematiku 2 na idućem roku!Ne gubi vrijeme učeći sam
# Done 947/1017
# Matemática 2.0 - Ejercicios resueltos de lógica matemática
# Done 948/1017
# Acentuación garantizada: un método definitivo
# Done 949/1017
# ม.ปลาย เซต (ตอนที่ 1)
# Done 950/1017
# Física
# Done 951/1017
# ม.ปลาย เซต (ตอนที่ 2)
# Done 952/1017
# สรุปเข้ม ม.1 คู่อันดับและกราฟ
# Done 953/1017
# สรุปเข้ม ม.1 ทศนิยมและเศษส่วน
# Done 954/1017
# สรุปเข้ม ม.1 พหุนาม
# Done 955/1017
# สรุปเข้ม ม.1 สมการเชิงเส้นตัวแปรเดียว
# Done 956/1017
# สรุปเข้ม ม.1 การประมาณค่า
# Done 957/1017
# Entendendo o Bullying
# Done 958/1017
# CÍRCULO TRIGONOMÉTRICO - CURSO INTRODUCTORIO
# Done 959/1017
# สรุปเข้ม ม.1 จำนวนและตัวเลข
# Done 960/1017
# Structural organisation in plants and animals
# Done 961/1017
# Comparative Politics and Global Issues
# Done 962/1017
# Reproduction
# Done 963/1017
# Matter and its Components
# Done 964/1017
# iSeahorse Trends: Finding & monitoring seahorse populations
# Done 965/1017
# Master the basics of Organic Chemistry
# Done 966/1017
# Introduction to Geology
# Done 967/1017
# First Year University Calculus: Partial Derivatives, Max/Min
# Done 968/1017
# Getting Started: Learning to Write Creative Non Fiction
# Done 969/1017
# GRIP ON PERCENTAGES -  Do any PERCENTAGE CALCULATION in SECS
# Done 970/1017
# Rate of Reactions
# Done 971/1017
# Chaos Complexity and  Emergence
# Done 972/1017
# สรุปเข้ม ม.2 การวัด
# Done 973/1017
# Curso de Iniciación a la narrativa con Francesc Miralles
# Done 974/1017
# สรุปเข้ม ม.3 กราฟ
# Done 975/1017
# ベイズ推定とグラフィカルモデル：コンピュータビジョン基礎1
# Done 976/1017
# Formación ciudadana y liderazgo
# Done 977/1017
# الإسعاف النفسي الأولي | Psychological First Aid
# Done 978/1017
# 統計學一 Statistics 1
# Done 979/1017
# Água, Produção Rural, Desenvolvimento e Sustentabilidade.
# Done 980/1017
# Diseño Mecánico Fácil Prueba
# Done 981/1017
# 微積分-基礎數學篇 Calculus-Basic Math
# Done 982/1017
# 7 ключей Эффективного Наставничества
# Done 983/1017
# Teoría Combinatoria (arreglos y combinaciones)
# Done 984/1017
# 統計學二 Statistics 2
# Done 985/1017
# 微積分-極限篇 Calculus-Limits
# Done 986/1017
# L'histoire littéraire de la Nouvelle-France
# Done 987/1017
# Математика с Mathcad-практикумом
# Done 988/1017
# الجينات لما تحكم
# Done 989/1017
# Освещение многообразия
# Done 990/1017
# SPSS ile Biyoistatistik Kursu "1  (Data Dosyası Oluşturma)
# Done 991/1017
# 微積分-導函數篇 Calculus-Derivatives
# Done 992/1017
# الشفافية ومكافحة الفساد
# Done 993/1017
# 微積分-指數與對數篇 Calculus-Exponential and Logarithmic Functions
# Done 994/1017
# 微積分-不定積分篇 Calculus-Indefinite Integrals
# Done 995/1017
# 微積分-導函數的應用篇 Calculus-Applications of Derivatives
# Done 996/1017
# Магическое мышление: Развитие и практические приложения
# Done 997/1017
# I-Number Logic 易數邏輯─易卦之斷卦法則與特殊卦象
# Done 998/1017
# Matematika (maktab kursi)
# Done 999/1017
# 透明和反腐
# Done 1000/1017
# 舌尖上的化学(第一季）
# Done 1001/1017
# Xlibris projekto metodologija
# Done 1002/1017
# I-Number Logic 易數邏輯─認識易經64卦與取卦應用
# Done 1003/1017
# KORNAROS – RIGAS - SOLOMOS
# Done 1004/1017
# สรุปเข้ม ม.1 การเตรียมความพร้อมในการให้เหตุผล
# Done 1005/1017
# Chant Populaire Grec
# Done 1006/1017
# 微積分-連續性篇 Calculus-Continuity
# Done 1007/1017
# 電気回路理論入門
# Done 1008/1017
# 微積分-三角函數篇 Calculus-Trigonometric Functions
# Done 1009/1017
# Einführung "Tourismus & Klimawandel"
# Done 1010/1017
# 企業年金講座０１　必見！　誰にでも必要な年金の知識
# Done 1011/1017
# 姚神谈民主 (简体中文)
# Done 1012/1017
# 그래프 특강
# Done 1013/1017
# Klimaangepasstes Destinations- und Unternehmensmanagement
# Done 1014/1017
# DSP晶片概論-THE CONCEPT OF DSP CHIP
# Done 1015/1017
# สรุปเข้ม ม.2 แผนภูมิวงกลม
# Done 1016/1017
# Algebra: equazioni e disequazioni di primo grado
# Done 1017/1017

# %%
save_course_data(get_udemy_curriculum("machine-learning-com-weka-e-java"))

# %%
def get_udemy_curriculum_deprecated(page):
    #Get page html object
    full_page = "https://www.udemy.com/" + page
    html = requests.get(full_page, timeout=60).text
    soup = BeautifulSoup(html, 'html.parser')
    
    data-course-id
    
    
    
    #Get page title
    curriculum = dict()
    title = soup.find("h1", {"class":"clp-lead__title"})
    if not title:
        raise Exception("Title not found")
    curriculum["title"] = title.get_text().strip()
    
    
    
    #Get curriculum data
    curriculum["children"] = list()
    curriculum_wrapper = soup.find("div", {"class": "curriculum-wrapper"})
    for content_container in curriculum_wrapper.find_all("div", {"class": "content-container"}):
        content_title_tag = content_container.find("span", {"class":"lecture-title-text"})
        if content_title_tag == None:
            continue
        content_title = content_title_tag.get_text().strip()
        content_children = list()
        
        for lecture_container in content_container.find_all("div", {"class":"lecture-container"}):
            content_child_title = lecture_container.find("div", {"class":"title"}).get_text().strip()
            content_children.append({"title":content_child_title})
        
        curriculum["children"].append({
            "title":content_title,
            "children": content_children
        })
    
    return curriculum

# %%
course_data = get_udemy_curriculum("machine-learning-com-weka-e-java")

# %%
print(course_data["title"])
for child in course_data["children"]:
    print("      " + child["title"])
    for child_2 in child["children"]:
        print("            " + child_2["title"])
# Out:
# Machine Learning com Weka e Java
#       Boas-vindas
#             Boas-vindas
#       Aprendizagem de máquina
#             Introdução
#             O que é aprendizagem de máquina
#             Métodos preditivos
#             Métodos descritivos I
#             Métodos descritivos II
#             Tipos de aprendizagem de máquina
#             Classificação I
#             Classificação II
#             Extração de características I
#             Extração de características II
#             Extração de características III
#             Reconhecimento dos personagens
#             Seleção de características dos personagens
#       Extrator de características
#             Introdução
#             Download das ferramentas
#             Entendendo a extração das cores
#             Instalação do projeto dos personagens
#             Código fonte do extrator de características I
#             Código fonte do extrator de características II
#             Código fonte do extrator de características III
#             Arquivo ARFF dos personagens
#             Carregando a imagem
#             Extração das características da imagem selecionada
#             Testando a extração das características
#             Base de dados para análise
#             Código fonte parcial
#       Introdução ao Weka
#             Introdução
#             Instalação do Weka
#             Introdução ao Weka
#             Entendendo os valores da janela inicial do Weka
#             Arquivos ARFF
#       Aprendizagem bayesiana
#             Introdução
#             Naive Bayes I
#             Naive Bayes II
#             Naive Bayes III
#             Naive Bayes IV
#             Naive Bayes no Weka
#             Carregando o ARFF dos personagens no Java
#             Classificando os personagens com o Naive Bayes
#             Código fonte parcial
#       Aprendizagem por árvores de decisão
#             Introdução
#       Aprendizagem por regras
#             Introdução
#       Aprendizagem baseada em instâncias
#             Introdução
#       Aprendizagem de redes neurais artificiais
#             Introdução
#       Aprendizagem de máquinas de vetores de suporte
#             Introdução
#       Outros algoritmos
#             Introdução
#       Avaliação dos algoritmos
#             Introdução
#       Combinação e rejeição de classificadores
#             Introdução
#       Considerações finais
#             Introdução
#             Saber mais sobre Inteligência Artificial
#             Cupons de desconto

# %%
html = download_page("https://www.udemy.com/data-science-deep-learning-in-theano-tensorflow/")

# %%
curriculum_wrapper = soup.find_all("div", {"class": "curriculum-wrapper"})

# %%
content_container = soup.find_all("div", {"class": "content-container"})

# %%
for content in content_container:
    print(content.find("span", {"class":"lecture-title-text"}).get_text())
# Out:
# Outline, the MNIST dataset, and Linear (Logistic Regression) Benchmark
# Gradient Descent: Full vs Batch vs Stochastic
# Momentum and adaptive learning rates
# Choosing Hyperparameters
# Theano
# TensorFlow
# Modern Regularization Techniques
# GPU Speedup, Homework, and Other Misc Topics
# Project: Facial Expression Recognition
# Appendix
